# %%
from datetime import datetime
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from fake_useragent import UserAgent
import sys
import re
import csv
import time
import pandas as pd
import requests

# %%
def extract_properties(links, writer):
    # need to get the first 6 articles, as the other 4 are the 'popular section'
    for link in links[:6]:
      # Within div tag, find h3 tag, then within h3 find 'a' tag, extract its title as text

      # Ex: Perolehan vaksin: Cubaan ketiga Anwar burukkan PN 

      article_title = link.find('h3').find('a').text

      # Ex: Date 2023-02-18T22:09:02+00:00
      date = link.find('time')['datetime'][:10]

      # Ex: 2023-02-18
      dateobj = datetime.strptime(date,'%Y-%m-%d').date()
      
      # Ex: 22:09:02+00:00 --> 22:09:02
      time = link.find('time')['datetime'][11:19]

      # Ex: 22:09:02 --> datetime format
      timeobj = datetime.strptime(time, '%H:%M:%S').time()

      # Extract value of href attribute from 'a' tag using dictionary-style access
      Link = link.find('h3').find('a')['href']

      # Extract post category website gave to each article 

      post_category = link.find('a', attrs={'class':'td-post-category'}).text

      # write each as a row in csv file
      writer.writerow([article_title, dateobj, timeobj, Link, post_category])

# %%
# Jan 2020 - Dec 2022 is in total 418 pages 

pages_to_get = 418

# Writing to a file 
with open('harakah_daily.csv', 'w', newline='') as f:
  writer = csv.writer(f)
  headers = ["Title", "Date", "Time", "Link", 'Post_Category']
  writer.writerow(headers)

  # automatic goes to the next page from 1... n; python exclusive end 

  for page in range(1,pages_to_get+1):
    print('Processing Page: ', page)
    url = 'https://harakahdaily.net/index.php/page/'+str(page)+'/?s=vaksin'

    try:
      # response is equivalent to enter a key in chrome 
      # prevent ip-block by adding fake devices accessing web pages 
      response = requests.get(url, headers={'User-Agent': UserAgent().random})

      # this link give valid status code: 200 --> web scrap pass 
      # print(page.status_code)

    except Exception as e:
      error_type, error_obj, error_info = sys.exc_info()
      print('Error Link: ', url)
      print(error_type, 'Line: ', error_info.tb_lineno)

      # ignore this paage and move on to next one
      continue 

    # delay by 2 seconds to prevent ip block
    time.sleep(2)

    soup = BeautifulSoup(response.text, 'html.parser')
    # inspect element attribute type and its names to take their information

    attrs_code = 'item-details'
    links = soup.find_all('div', attrs={'class':attrs_code})
    # print(len(links))

    # Check each page has 6 links
    print(f'This page has {len(links[:6])} links')

    extract_properties(links, writer)

    print('CSV file saved successfully for Page: ' + str(page))
# Out:
# Processing Page:  1
# This page has 6 links
# CSV file saved successfully for Page: 1
# Processing Page:  2
# This page has 6 links
# CSV file saved successfully for Page: 2
# Processing Page:  3
# This page has 6 links
# CSV file saved successfully for Page: 3
# Processing Page:  4
# This page has 6 links
# CSV file saved successfully for Page: 4
# Processing Page:  5
# This page has 6 links
# CSV file saved successfully for Page: 5
# Processing Page:  6
# This page has 6 links
# CSV file saved successfully for Page: 6
# Processing Page:  7
# This page has 6 links
# CSV file saved successfully for Page: 7
# Processing Page:  8
# This page has 6 links
# CSV file saved successfully for Page: 8
# Processing Page:  9
# This page has 6 links
# CSV file saved successfully for Page: 9
# Processing Page:  10
# This page has 6 links
# CSV file saved successfully for Page: 10
# Processing Page:  11
# This page has 6 links
# CSV file saved successfully for Page: 11
# Processing Page:  12
# This page has 6 links
# CSV file saved successfully for Page: 12
# Processing Page:  13
# This page has 6 links
# CSV file saved successfully for Page: 13
# Processing Page:  14
# This page has 6 links
# CSV file saved successfully for Page: 14
# Processing Page:  15
# This page has 6 links
# CSV file saved successfully for Page: 15
# Processing Page:  16
# This page has 6 links
# CSV file saved successfully for Page: 16
# Processing Page:  17
# This page has 6 links
# CSV file saved successfully for Page: 17
# Processing Page:  18
# This page has 6 links
# CSV file saved successfully for Page: 18
# Processing Page:  19
# This page has 6 links
# CSV file saved successfully for Page: 19
# Processing Page:  20
# This page has 6 links
# CSV file saved successfully for Page: 20
# Processing Page:  21
# This page has 6 links
# CSV file saved successfully for Page: 21
# Processing Page:  22
# This page has 6 links
# CSV file saved successfully for Page: 22
# Processing Page:  23
# This page has 6 links
# CSV file saved successfully for Page: 23
# Processing Page:  24
# This page has 6 links
# CSV file saved successfully for Page: 24
# Processing Page:  25
# This page has 6 links
# CSV file saved successfully for Page: 25
# Processing Page:  26
# This page has 6 links
# CSV file saved successfully for Page: 26
# Processing Page:  27
# This page has 6 links
# CSV file saved successfully for Page: 27
# Processing Page:  28
# This page has 6 links
# CSV file saved successfully for Page: 28
# Processing Page:  29
# This page has 6 links
# CSV file saved successfully for Page: 29
# Processing Page:  30
# This page has 6 links
# CSV file saved successfully for Page: 30
# Processing Page:  31
# This page has 6 links
# CSV file saved successfully for Page: 31
# Processing Page:  32
# This page has 6 links
# CSV file saved successfully for Page: 32
# Processing Page:  33
# This page has 6 links
# CSV file saved successfully for Page: 33
# Processing Page:  34
# This page has 6 links
# CSV file saved successfully for Page: 34
# Processing Page:  35
# This page has 6 links
# CSV file saved successfully for Page: 35
# Processing Page:  36
# This page has 6 links
# CSV file saved successfully for Page: 36
# Processing Page:  37
# This page has 6 links
# CSV file saved successfully for Page: 37
# Processing Page:  38
# This page has 6 links
# CSV file saved successfully for Page: 38
# Processing Page:  39
# This page has 6 links
# CSV file saved successfully for Page: 39
# Processing Page:  40
# This page has 6 links
# CSV file saved successfully for Page: 40
# Processing Page:  41
# This page has 6 links
# CSV file saved successfully for Page: 41
# Processing Page:  42
# This page has 6 links
# CSV file saved successfully for Page: 42
# Processing Page:  43
# This page has 6 links
# CSV file saved successfully for Page: 43
# Processing Page:  44
# This page has 6 links
# CSV file saved successfully for Page: 44
# Processing Page:  45
# This page has 6 links
# CSV file saved successfully for Page: 45
# Processing Page:  46
# This page has 6 links
# CSV file saved successfully for Page: 46
# Processing Page:  47
# This page has 6 links
# CSV file saved successfully for Page: 47
# Processing Page:  48
# This page has 6 links
# CSV file saved successfully for Page: 48
# Processing Page:  49
# This page has 6 links
# CSV file saved successfully for Page: 49
# Processing Page:  50
# This page has 6 links
# CSV file saved successfully for Page: 50
# Processing Page:  51
# This page has 6 links
# CSV file saved successfully for Page: 51
# Processing Page:  52
# This page has 6 links
# CSV file saved successfully for Page: 52
# Processing Page:  53
# This page has 6 links
# CSV file saved successfully for Page: 53
# Processing Page:  54
# This page has 6 links
# CSV file saved successfully for Page: 54
# Processing Page:  55
# This page has 6 links
# CSV file saved successfully for Page: 55
# Processing Page:  56
# This page has 6 links
# CSV file saved successfully for Page: 56
# Processing Page:  57
# This page has 6 links
# CSV file saved successfully for Page: 57
# Processing Page:  58
# This page has 6 links
# CSV file saved successfully for Page: 58
# Processing Page:  59
# This page has 6 links
# CSV file saved successfully for Page: 59
# Processing Page:  60
# This page has 6 links
# CSV file saved successfully for Page: 60
# Processing Page:  61
# This page has 6 links
# CSV file saved successfully for Page: 61
# Processing Page:  62
# This page has 6 links
# CSV file saved successfully for Page: 62
# Processing Page:  63
# This page has 6 links
# CSV file saved successfully for Page: 63
# Processing Page:  64
# This page has 6 links
# CSV file saved successfully for Page: 64
# Processing Page:  65
# This page has 6 links
# CSV file saved successfully for Page: 65
# Processing Page:  66
# This page has 6 links
# CSV file saved successfully for Page: 66
# Processing Page:  67
# This page has 6 links
# CSV file saved successfully for Page: 67
# Processing Page:  68
# This page has 6 links
# CSV file saved successfully for Page: 68
# Processing Page:  69
# This page has 6 links
# CSV file saved successfully for Page: 69
# Processing Page:  70
# This page has 6 links
# CSV file saved successfully for Page: 70
# Processing Page:  71
# This page has 6 links
# CSV file saved successfully for Page: 71
# Processing Page:  72
# This page has 6 links
# CSV file saved successfully for Page: 72
# Processing Page:  73
# This page has 6 links
# CSV file saved successfully for Page: 73
# Processing Page:  74
# This page has 6 links
# CSV file saved successfully for Page: 74
# Processing Page:  75
# This page has 6 links
# CSV file saved successfully for Page: 75
# Processing Page:  76
# This page has 6 links
# CSV file saved successfully for Page: 76
# Processing Page:  77
# This page has 6 links
# CSV file saved successfully for Page: 77
# Processing Page:  78
# This page has 6 links
# CSV file saved successfully for Page: 78
# Processing Page:  79
# This page has 6 links
# CSV file saved successfully for Page: 79
# Processing Page:  80
# This page has 6 links
# CSV file saved successfully for Page: 80
# Processing Page:  81
# This page has 6 links
# CSV file saved successfully for Page: 81
# Processing Page:  82
# This page has 6 links
# CSV file saved successfully for Page: 82
# Processing Page:  83
# This page has 6 links
# CSV file saved successfully for Page: 83
# Processing Page:  84
# This page has 6 links
# CSV file saved successfully for Page: 84
# Processing Page:  85
# This page has 6 links
# CSV file saved successfully for Page: 85
# Processing Page:  86
# This page has 6 links
# CSV file saved successfully for Page: 86
# Processing Page:  87
# This page has 6 links
# CSV file saved successfully for Page: 87
# Processing Page:  88
# This page has 6 links
# CSV file saved successfully for Page: 88
# Processing Page:  89
# This page has 6 links
# CSV file saved successfully for Page: 89
# Processing Page:  90
# This page has 6 links
# CSV file saved successfully for Page: 90
# Processing Page:  91
# This page has 6 links
# CSV file saved successfully for Page: 91
# Processing Page:  92
# This page has 6 links
# CSV file saved successfully for Page: 92
# Processing Page:  93
# This page has 6 links
# CSV file saved successfully for Page: 93
# Processing Page:  94
# This page has 6 links
# CSV file saved successfully for Page: 94
# Processing Page:  95
# This page has 6 links
# CSV file saved successfully for Page: 95
# Processing Page:  96
# This page has 6 links
# CSV file saved successfully for Page: 96
# Processing Page:  97
# This page has 6 links
# CSV file saved successfully for Page: 97
# Processing Page:  98
# This page has 6 links
# CSV file saved successfully for Page: 98
# Processing Page:  99
# This page has 6 links
# CSV file saved successfully for Page: 99
# Processing Page:  100
# This page has 6 links
# CSV file saved successfully for Page: 100
# Processing Page:  101
# This page has 6 links
# CSV file saved successfully for Page: 101
# Processing Page:  102
# This page has 6 links
# CSV file saved successfully for Page: 102
# Processing Page:  103
# This page has 6 links
# CSV file saved successfully for Page: 103
# Processing Page:  104
# This page has 6 links
# CSV file saved successfully for Page: 104
# Processing Page:  105
# This page has 6 links
# CSV file saved successfully for Page: 105
# Processing Page:  106
# This page has 6 links
# CSV file saved successfully for Page: 106
# Processing Page:  107
# This page has 6 links
# CSV file saved successfully for Page: 107
# Processing Page:  108
# This page has 6 links
# CSV file saved successfully for Page: 108
# Processing Page:  109
# This page has 6 links
# CSV file saved successfully for Page: 109
# Processing Page:  110
# This page has 6 links
# CSV file saved successfully for Page: 110
# Processing Page:  111
# This page has 6 links
# CSV file saved successfully for Page: 111
# Processing Page:  112
# This page has 6 links
# CSV file saved successfully for Page: 112
# Processing Page:  113
# This page has 6 links
# CSV file saved successfully for Page: 113
# Processing Page:  114
# This page has 6 links
# CSV file saved successfully for Page: 114
# Processing Page:  115
# This page has 6 links
# CSV file saved successfully for Page: 115
# Processing Page:  116
# This page has 6 links
# CSV file saved successfully for Page: 116
# Processing Page:  117
# This page has 6 links
# CSV file saved successfully for Page: 117
# Processing Page:  118
# This page has 6 links
# CSV file saved successfully for Page: 118
# Processing Page:  119
# This page has 6 links
# CSV file saved successfully for Page: 119
# Processing Page:  120
# This page has 6 links
# CSV file saved successfully for Page: 120
# Processing Page:  121
# This page has 6 links
# CSV file saved successfully for Page: 121
# Processing Page:  122
# This page has 6 links
# CSV file saved successfully for Page: 122
# Processing Page:  123
# This page has 6 links
# CSV file saved successfully for Page: 123
# Processing Page:  124
# This page has 6 links
# CSV file saved successfully for Page: 124
# Processing Page:  125
# This page has 6 links
# CSV file saved successfully for Page: 125
# Processing Page:  126
# This page has 6 links
# CSV file saved successfully for Page: 126
# Processing Page:  127
# This page has 6 links
# CSV file saved successfully for Page: 127
# Processing Page:  128
# This page has 6 links
# CSV file saved successfully for Page: 128
# Processing Page:  129
# This page has 6 links
# CSV file saved successfully for Page: 129
# Processing Page:  130
# This page has 6 links
# CSV file saved successfully for Page: 130
# Processing Page:  131
# This page has 6 links
# CSV file saved successfully for Page: 131
# Processing Page:  132
# This page has 6 links
# CSV file saved successfully for Page: 132
# Processing Page:  133
# This page has 6 links
# CSV file saved successfully for Page: 133
# Processing Page:  134
# This page has 6 links
# CSV file saved successfully for Page: 134
# Processing Page:  135
# This page has 6 links
# CSV file saved successfully for Page: 135
# Processing Page:  136
# This page has 6 links
# CSV file saved successfully for Page: 136
# Processing Page:  137
# This page has 6 links
# CSV file saved successfully for Page: 137
# Processing Page:  138
# This page has 6 links
# CSV file saved successfully for Page: 138
# Processing Page:  139
# This page has 6 links
# CSV file saved successfully for Page: 139
# Processing Page:  140
# This page has 6 links
# CSV file saved successfully for Page: 140
# Processing Page:  141
# This page has 6 links
# CSV file saved successfully for Page: 141
# Processing Page:  142
# This page has 6 links
# CSV file saved successfully for Page: 142
# Processing Page:  143
# This page has 6 links
# CSV file saved successfully for Page: 143
# Processing Page:  144
# This page has 6 links
# CSV file saved successfully for Page: 144
# Processing Page:  145
# This page has 6 links
# CSV file saved successfully for Page: 145
# Processing Page:  146
# This page has 6 links
# CSV file saved successfully for Page: 146
# Processing Page:  147
# This page has 6 links
# CSV file saved successfully for Page: 147
# Processing Page:  148
# This page has 6 links
# CSV file saved successfully for Page: 148
# Processing Page:  149
# This page has 6 links
# CSV file saved successfully for Page: 149
# Processing Page:  150
# This page has 6 links
# CSV file saved successfully for Page: 150
# Processing Page:  151
# This page has 6 links
# CSV file saved successfully for Page: 151
# Processing Page:  152
# This page has 6 links
# CSV file saved successfully for Page: 152
# Processing Page:  153
# This page has 6 links
# CSV file saved successfully for Page: 153
# Processing Page:  154
# This page has 6 links
# CSV file saved successfully for Page: 154
# Processing Page:  155
# This page has 6 links
# CSV file saved successfully for Page: 155
# Processing Page:  156
# This page has 6 links
# CSV file saved successfully for Page: 156
# Processing Page:  157
# This page has 6 links
# CSV file saved successfully for Page: 157
# Processing Page:  158
# This page has 6 links
# CSV file saved successfully for Page: 158
# Processing Page:  159
# This page has 6 links
# CSV file saved successfully for Page: 159
# Processing Page:  160
# This page has 6 links
# CSV file saved successfully for Page: 160
# Processing Page:  161
# This page has 6 links
# CSV file saved successfully for Page: 161
# Processing Page:  162
# This page has 6 links
# CSV file saved successfully for Page: 162
# Processing Page:  163
# This page has 6 links
# CSV file saved successfully for Page: 163
# Processing Page:  164
# This page has 6 links
# CSV file saved successfully for Page: 164
# Processing Page:  165
# This page has 6 links
# CSV file saved successfully for Page: 165
# Processing Page:  166
# This page has 6 links
# CSV file saved successfully for Page: 166
# Processing Page:  167
# This page has 6 links
# CSV file saved successfully for Page: 167
# Processing Page:  168
# This page has 6 links
# CSV file saved successfully for Page: 168
# Processing Page:  169
# This page has 6 links
# CSV file saved successfully for Page: 169
# Processing Page:  170
# This page has 6 links
# CSV file saved successfully for Page: 170
# Processing Page:  171
# This page has 6 links
# CSV file saved successfully for Page: 171
# Processing Page:  172
# This page has 6 links
# CSV file saved successfully for Page: 172
# Processing Page:  173
# This page has 6 links
# CSV file saved successfully for Page: 173
# Processing Page:  174
# This page has 6 links
# CSV file saved successfully for Page: 174
# Processing Page:  175
# This page has 6 links
# CSV file saved successfully for Page: 175
# Processing Page:  176
# This page has 6 links
# CSV file saved successfully for Page: 176
# Processing Page:  177
# This page has 6 links
# CSV file saved successfully for Page: 177
# Processing Page:  178
# This page has 6 links
# CSV file saved successfully for Page: 178
# Processing Page:  179
# This page has 6 links
# CSV file saved successfully for Page: 179
# Processing Page:  180
# This page has 6 links
# CSV file saved successfully for Page: 180
# Processing Page:  181
# This page has 6 links
# CSV file saved successfully for Page: 181
# Processing Page:  182
# This page has 6 links
# CSV file saved successfully for Page: 182
# Processing Page:  183
# This page has 6 links
# CSV file saved successfully for Page: 183
# Processing Page:  184
# This page has 6 links
# CSV file saved successfully for Page: 184
# Processing Page:  185
# This page has 6 links
# CSV file saved successfully for Page: 185
# Processing Page:  186
# This page has 6 links
# CSV file saved successfully for Page: 186
# Processing Page:  187
# This page has 6 links
# CSV file saved successfully for Page: 187
# Processing Page:  188
# This page has 6 links
# CSV file saved successfully for Page: 188
# Processing Page:  189
# This page has 6 links
# CSV file saved successfully for Page: 189
# Processing Page:  190
# This page has 6 links
# CSV file saved successfully for Page: 190
# Processing Page:  191
# This page has 6 links
# CSV file saved successfully for Page: 191
# Processing Page:  192
# This page has 6 links
# CSV file saved successfully for Page: 192
# Processing Page:  193
# This page has 6 links
# CSV file saved successfully for Page: 193
# Processing Page:  194
# This page has 6 links
# CSV file saved successfully for Page: 194
# Processing Page:  195
# This page has 6 links
# CSV file saved successfully for Page: 195
# Processing Page:  196
# This page has 6 links
# CSV file saved successfully for Page: 196
# Processing Page:  197
# This page has 6 links
# CSV file saved successfully for Page: 197
# Processing Page:  198
# This page has 6 links
# CSV file saved successfully for Page: 198
# Processing Page:  199
# This page has 6 links
# CSV file saved successfully for Page: 199
# Processing Page:  200
# This page has 6 links
# CSV file saved successfully for Page: 200
# Processing Page:  201
# This page has 6 links
# CSV file saved successfully for Page: 201
# Processing Page:  202
# This page has 6 links
# CSV file saved successfully for Page: 202
# Processing Page:  203
# This page has 6 links
# CSV file saved successfully for Page: 203
# Processing Page:  204
# This page has 6 links
# CSV file saved successfully for Page: 204
# Processing Page:  205
# This page has 6 links
# CSV file saved successfully for Page: 205
# Processing Page:  206
# This page has 6 links
# CSV file saved successfully for Page: 206
# Processing Page:  207
# This page has 6 links
# CSV file saved successfully for Page: 207
# Processing Page:  208
# This page has 6 links
# CSV file saved successfully for Page: 208
# Processing Page:  209
# This page has 6 links
# CSV file saved successfully for Page: 209
# Processing Page:  210
# This page has 6 links
# CSV file saved successfully for Page: 210
# Processing Page:  211
# This page has 6 links
# CSV file saved successfully for Page: 211
# Processing Page:  212
# This page has 6 links
# CSV file saved successfully for Page: 212
# Processing Page:  213
# This page has 6 links
# CSV file saved successfully for Page: 213
# Processing Page:  214
# This page has 6 links
# CSV file saved successfully for Page: 214
# Processing Page:  215
# This page has 6 links
# CSV file saved successfully for Page: 215
# Processing Page:  216
# This page has 6 links
# CSV file saved successfully for Page: 216
# Processing Page:  217
# This page has 6 links
# CSV file saved successfully for Page: 217
# Processing Page:  218
# This page has 6 links
# CSV file saved successfully for Page: 218
# Processing Page:  219
# This page has 6 links
# CSV file saved successfully for Page: 219
# Processing Page:  220
# This page has 6 links
# CSV file saved successfully for Page: 220
# Processing Page:  221
# This page has 6 links
# CSV file saved successfully for Page: 221
# Processing Page:  222
# This page has 6 links
# CSV file saved successfully for Page: 222
# Processing Page:  223
# This page has 6 links
# CSV file saved successfully for Page: 223
# Processing Page:  224
# This page has 6 links
# CSV file saved successfully for Page: 224
# Processing Page:  225
# This page has 6 links
# CSV file saved successfully for Page: 225
# Processing Page:  226
# This page has 6 links
# CSV file saved successfully for Page: 226
# Processing Page:  227
# This page has 6 links
# CSV file saved successfully for Page: 227
# Processing Page:  228
# This page has 6 links
# CSV file saved successfully for Page: 228
# Processing Page:  229
# This page has 6 links
# CSV file saved successfully for Page: 229
# Processing Page:  230
# This page has 6 links
# CSV file saved successfully for Page: 230
# Processing Page:  231
# This page has 6 links
# CSV file saved successfully for Page: 231
# Processing Page:  232
# This page has 6 links
# CSV file saved successfully for Page: 232
# Processing Page:  233
# This page has 6 links
# CSV file saved successfully for Page: 233
# Processing Page:  234
# This page has 6 links
# CSV file saved successfully for Page: 234
# Processing Page:  235
# This page has 6 links
# CSV file saved successfully for Page: 235
# Processing Page:  236
# This page has 6 links
# CSV file saved successfully for Page: 236
# Processing Page:  237
# This page has 6 links
# CSV file saved successfully for Page: 237
# Processing Page:  238
# This page has 6 links
# CSV file saved successfully for Page: 238
# Processing Page:  239
# This page has 6 links
# CSV file saved successfully for Page: 239
# Processing Page:  240
# This page has 6 links
# CSV file saved successfully for Page: 240
# Processing Page:  241
# This page has 6 links
# CSV file saved successfully for Page: 241
# Processing Page:  242
# This page has 6 links
# CSV file saved successfully for Page: 242
# Processing Page:  243
# This page has 6 links
# CSV file saved successfully for Page: 243
# Processing Page:  244
# This page has 6 links
# CSV file saved successfully for Page: 244
# Processing Page:  245
# This page has 6 links
# CSV file saved successfully for Page: 245
# Processing Page:  246
# This page has 6 links
# CSV file saved successfully for Page: 246
# Processing Page:  247
# This page has 6 links
# CSV file saved successfully for Page: 247
# Processing Page:  248
# This page has 6 links
# CSV file saved successfully for Page: 248
# Processing Page:  249
# This page has 6 links
# CSV file saved successfully for Page: 249
# Processing Page:  250
# This page has 6 links
# CSV file saved successfully for Page: 250
# Processing Page:  251
# This page has 6 links
# CSV file saved successfully for Page: 251
# Processing Page:  252
# This page has 6 links
# CSV file saved successfully for Page: 252
# Processing Page:  253
# This page has 6 links
# CSV file saved successfully for Page: 253
# Processing Page:  254
# This page has 6 links
# CSV file saved successfully for Page: 254
# Processing Page:  255
# This page has 6 links
# CSV file saved successfully for Page: 255
# Processing Page:  256
# This page has 6 links
# CSV file saved successfully for Page: 256
# Processing Page:  257
# This page has 6 links
# CSV file saved successfully for Page: 257
# Processing Page:  258
# This page has 6 links
# CSV file saved successfully for Page: 258
# Processing Page:  259
# This page has 6 links
# CSV file saved successfully for Page: 259
# Processing Page:  260
# This page has 6 links
# CSV file saved successfully for Page: 260
# Processing Page:  261
# This page has 6 links
# CSV file saved successfully for Page: 261
# Processing Page:  262
# This page has 6 links
# CSV file saved successfully for Page: 262
# Processing Page:  263
# This page has 6 links
# CSV file saved successfully for Page: 263
# Processing Page:  264
# This page has 6 links
# CSV file saved successfully for Page: 264
# Processing Page:  265
# This page has 6 links
# CSV file saved successfully for Page: 265
# Processing Page:  266
# This page has 6 links
# CSV file saved successfully for Page: 266
# Processing Page:  267
# This page has 6 links
# CSV file saved successfully for Page: 267
# Processing Page:  268
# This page has 6 links
# CSV file saved successfully for Page: 268
# Processing Page:  269
# This page has 6 links
# CSV file saved successfully for Page: 269
# Processing Page:  270
# This page has 6 links
# CSV file saved successfully for Page: 270
# Processing Page:  271
# This page has 6 links
# CSV file saved successfully for Page: 271
# Processing Page:  272
# This page has 6 links
# CSV file saved successfully for Page: 272
# Processing Page:  273
# This page has 6 links
# CSV file saved successfully for Page: 273
# Processing Page:  274
# This page has 6 links
# CSV file saved successfully for Page: 274
# Processing Page:  275
# This page has 6 links
# CSV file saved successfully for Page: 275
# Processing Page:  276
# This page has 6 links
# CSV file saved successfully for Page: 276
# Processing Page:  277
# This page has 6 links
# CSV file saved successfully for Page: 277
# Processing Page:  278
# This page has 6 links
# CSV file saved successfully for Page: 278
# Processing Page:  279
# This page has 6 links
# CSV file saved successfully for Page: 279
# Processing Page:  280
# This page has 6 links
# CSV file saved successfully for Page: 280
# Processing Page:  281
# This page has 6 links
# CSV file saved successfully for Page: 281
# Processing Page:  282
# This page has 6 links
# CSV file saved successfully for Page: 282
# Processing Page:  283
# This page has 6 links
# CSV file saved successfully for Page: 283
# Processing Page:  284
# This page has 6 links
# CSV file saved successfully for Page: 284
# Processing Page:  285
# This page has 6 links
# CSV file saved successfully for Page: 285
# Processing Page:  286
# This page has 6 links
# CSV file saved successfully for Page: 286
# Processing Page:  287
# This page has 6 links
# CSV file saved successfully for Page: 287
# Processing Page:  288
# This page has 6 links
# CSV file saved successfully for Page: 288
# Processing Page:  289
# This page has 6 links
# CSV file saved successfully for Page: 289
# Processing Page:  290
# This page has 6 links
# CSV file saved successfully for Page: 290
# Processing Page:  291
# This page has 6 links
# CSV file saved successfully for Page: 291
# Processing Page:  292
# This page has 6 links
# CSV file saved successfully for Page: 292
# Processing Page:  293
# This page has 6 links
# CSV file saved successfully for Page: 293
# Processing Page:  294
# This page has 6 links
# CSV file saved successfully for Page: 294
# Processing Page:  295
# This page has 6 links
# CSV file saved successfully for Page: 295
# Processing Page:  296
# This page has 6 links
# CSV file saved successfully for Page: 296
# Processing Page:  297
# This page has 6 links
# CSV file saved successfully for Page: 297
# Processing Page:  298
# This page has 6 links
# CSV file saved successfully for Page: 298
# Processing Page:  299
# This page has 6 links
# CSV file saved successfully for Page: 299
# Processing Page:  300
# This page has 6 links
# CSV file saved successfully for Page: 300
# Processing Page:  301
# This page has 6 links
# CSV file saved successfully for Page: 301
# Processing Page:  302
# This page has 6 links
# CSV file saved successfully for Page: 302
# Processing Page:  303
# This page has 6 links
# CSV file saved successfully for Page: 303
# Processing Page:  304
# This page has 6 links
# CSV file saved successfully for Page: 304
# Processing Page:  305
# This page has 6 links
# CSV file saved successfully for Page: 305
# Processing Page:  306
# This page has 6 links
# CSV file saved successfully for Page: 306
# Processing Page:  307
# This page has 6 links
# CSV file saved successfully for Page: 307
# Processing Page:  308
# This page has 6 links
# CSV file saved successfully for Page: 308
# Processing Page:  309
# This page has 6 links
# CSV file saved successfully for Page: 309
# Processing Page:  310
# This page has 6 links
# CSV file saved successfully for Page: 310
# Processing Page:  311
# This page has 6 links
# CSV file saved successfully for Page: 311
# Processing Page:  312
# This page has 6 links
# CSV file saved successfully for Page: 312
# Processing Page:  313
# This page has 6 links
# CSV file saved successfully for Page: 313
# Processing Page:  314
# This page has 6 links
# CSV file saved successfully for Page: 314
# Processing Page:  315
# This page has 6 links
# CSV file saved successfully for Page: 315
# Processing Page:  316
# This page has 6 links
# CSV file saved successfully for Page: 316
# Processing Page:  317
# This page has 6 links
# CSV file saved successfully for Page: 317
# Processing Page:  318
# This page has 6 links
# CSV file saved successfully for Page: 318
# Processing Page:  319
# This page has 6 links
# CSV file saved successfully for Page: 319
# Processing Page:  320
# This page has 6 links
# CSV file saved successfully for Page: 320
# Processing Page:  321
# This page has 6 links
# CSV file saved successfully for Page: 321
# Processing Page:  322
# This page has 6 links
# CSV file saved successfully for Page: 322
# Processing Page:  323
# This page has 6 links
# CSV file saved successfully for Page: 323
# Processing Page:  324
# This page has 6 links
# CSV file saved successfully for Page: 324
# Processing Page:  325
# This page has 6 links
# CSV file saved successfully for Page: 325
# Processing Page:  326
# This page has 6 links
# CSV file saved successfully for Page: 326
# Processing Page:  327
# This page has 6 links
# CSV file saved successfully for Page: 327
# Processing Page:  328
# This page has 6 links
# CSV file saved successfully for Page: 328
# Processing Page:  329
# This page has 6 links
# CSV file saved successfully for Page: 329
# Processing Page:  330
# This page has 6 links
# CSV file saved successfully for Page: 330
# Processing Page:  331
# This page has 6 links
# CSV file saved successfully for Page: 331
# Processing Page:  332
# This page has 6 links
# CSV file saved successfully for Page: 332
# Processing Page:  333
# This page has 6 links
# CSV file saved successfully for Page: 333
# Processing Page:  334
# This page has 6 links
# CSV file saved successfully for Page: 334
# Processing Page:  335
# This page has 6 links
# CSV file saved successfully for Page: 335
# Processing Page:  336
# This page has 6 links
# CSV file saved successfully for Page: 336
# Processing Page:  337
# This page has 6 links
# CSV file saved successfully for Page: 337
# Processing Page:  338
# This page has 6 links
# CSV file saved successfully for Page: 338
# Processing Page:  339
# This page has 6 links
# CSV file saved successfully for Page: 339
# Processing Page:  340
# This page has 6 links
# CSV file saved successfully for Page: 340
# Processing Page:  341
# This page has 6 links
# CSV file saved successfully for Page: 341
# Processing Page:  342
# This page has 6 links
# CSV file saved successfully for Page: 342
# Processing Page:  343
# This page has 6 links
# CSV file saved successfully for Page: 343
# Processing Page:  344
# This page has 6 links
# CSV file saved successfully for Page: 344
# Processing Page:  345
# This page has 6 links
# CSV file saved successfully for Page: 345
# Processing Page:  346
# This page has 6 links
# CSV file saved successfully for Page: 346
# Processing Page:  347
# This page has 6 links
# CSV file saved successfully for Page: 347
# Processing Page:  348
# This page has 6 links
# CSV file saved successfully for Page: 348
# Processing Page:  349
# This page has 6 links
# CSV file saved successfully for Page: 349
# Processing Page:  350
# This page has 6 links
# CSV file saved successfully for Page: 350
# Processing Page:  351
# This page has 6 links
# CSV file saved successfully for Page: 351
# Processing Page:  352
# This page has 6 links
# CSV file saved successfully for Page: 352
# Processing Page:  353
# This page has 6 links
# CSV file saved successfully for Page: 353
# Processing Page:  354
# This page has 6 links
# CSV file saved successfully for Page: 354
# Processing Page:  355
# This page has 6 links
# CSV file saved successfully for Page: 355
# Processing Page:  356
# This page has 6 links
# CSV file saved successfully for Page: 356
# Processing Page:  357
# This page has 6 links
# CSV file saved successfully for Page: 357
# Processing Page:  358
# This page has 6 links
# CSV file saved successfully for Page: 358
# Processing Page:  359
# This page has 6 links
# CSV file saved successfully for Page: 359
# Processing Page:  360
# This page has 6 links
# CSV file saved successfully for Page: 360
# Processing Page:  361
# This page has 6 links
# CSV file saved successfully for Page: 361
# Processing Page:  362
# This page has 6 links
# CSV file saved successfully for Page: 362
# Processing Page:  363
# This page has 6 links
# CSV file saved successfully for Page: 363
# Processing Page:  364
# This page has 6 links
# CSV file saved successfully for Page: 364
# Processing Page:  365
# This page has 6 links
# CSV file saved successfully for Page: 365
# Processing Page:  366
# This page has 6 links
# CSV file saved successfully for Page: 366
# Processing Page:  367
# This page has 6 links
# CSV file saved successfully for Page: 367
# Processing Page:  368
# This page has 6 links
# CSV file saved successfully for Page: 368
# Processing Page:  369
# This page has 6 links
# CSV file saved successfully for Page: 369
# Processing Page:  370
# This page has 6 links
# CSV file saved successfully for Page: 370
# Processing Page:  371
# This page has 6 links
# CSV file saved successfully for Page: 371
# Processing Page:  372
# This page has 6 links
# CSV file saved successfully for Page: 372
# Processing Page:  373
# This page has 6 links
# CSV file saved successfully for Page: 373
# Processing Page:  374
# This page has 6 links
# CSV file saved successfully for Page: 374
# Processing Page:  375
# This page has 6 links
# CSV file saved successfully for Page: 375
# Processing Page:  376
# This page has 6 links
# CSV file saved successfully for Page: 376
# Processing Page:  377
# This page has 6 links
# CSV file saved successfully for Page: 377
# Processing Page:  378
# This page has 6 links
# CSV file saved successfully for Page: 378
# Processing Page:  379
# This page has 6 links
# CSV file saved successfully for Page: 379
# Processing Page:  380
# This page has 6 links
# CSV file saved successfully for Page: 380
# Processing Page:  381
# This page has 6 links
# CSV file saved successfully for Page: 381
# Processing Page:  382
# This page has 6 links
# CSV file saved successfully for Page: 382
# Processing Page:  383
# This page has 6 links
# CSV file saved successfully for Page: 383
# Processing Page:  384
# This page has 6 links
# CSV file saved successfully for Page: 384
# Processing Page:  385
# This page has 6 links
# CSV file saved successfully for Page: 385
# Processing Page:  386
# This page has 6 links
# CSV file saved successfully for Page: 386
# Processing Page:  387
# This page has 6 links
# CSV file saved successfully for Page: 387
# Processing Page:  388
# This page has 6 links
# CSV file saved successfully for Page: 388
# Processing Page:  389
# This page has 6 links
# CSV file saved successfully for Page: 389
# Processing Page:  390
# This page has 6 links
# CSV file saved successfully for Page: 390
# Processing Page:  391
# This page has 6 links
# CSV file saved successfully for Page: 391
# Processing Page:  392
# This page has 6 links
# CSV file saved successfully for Page: 392
# Processing Page:  393
# This page has 6 links
# CSV file saved successfully for Page: 393
# Processing Page:  394
# This page has 6 links
# CSV file saved successfully for Page: 394
# Processing Page:  395
# This page has 6 links
# CSV file saved successfully for Page: 395
# Processing Page:  396
# This page has 6 links
# CSV file saved successfully for Page: 396
# Processing Page:  397
# This page has 6 links
# CSV file saved successfully for Page: 397
# Processing Page:  398
# This page has 6 links
# CSV file saved successfully for Page: 398
# Processing Page:  399
# This page has 6 links
# CSV file saved successfully for Page: 399
# Processing Page:  400
# This page has 6 links
# CSV file saved successfully for Page: 400
# Processing Page:  401
# This page has 6 links
# CSV file saved successfully for Page: 401
# Processing Page:  402
# This page has 6 links
# CSV file saved successfully for Page: 402
# Processing Page:  403
# This page has 6 links
# CSV file saved successfully for Page: 403
# Processing Page:  404
# This page has 6 links
# CSV file saved successfully for Page: 404
# Processing Page:  405
# This page has 6 links
# CSV file saved successfully for Page: 405
# Processing Page:  406
# This page has 6 links
# CSV file saved successfully for Page: 406
# Processing Page:  407
# This page has 6 links
# CSV file saved successfully for Page: 407
# Processing Page:  408
# This page has 6 links
# CSV file saved successfully for Page: 408
# Processing Page:  409
# This page has 6 links
# CSV file saved successfully for Page: 409
# Processing Page:  410
# This page has 6 links
# CSV file saved successfully for Page: 410
# Processing Page:  411
# This page has 6 links
# CSV file saved successfully for Page: 411
# Processing Page:  412
# This page has 6 links
# CSV file saved successfully for Page: 412
# Processing Page:  413
# This page has 6 links
# CSV file saved successfully for Page: 413
# Processing Page:  414
# This page has 6 links
# CSV file saved successfully for Page: 414
# Processing Page:  415
# This page has 6 links
# CSV file saved successfully for Page: 415
# Processing Page:  416
# This page has 6 links
# CSV file saved successfully for Page: 416
# Processing Page:  417
# This page has 6 links
# CSV file saved successfully for Page: 417
# Processing Page:  418
# This page has 6 links
# CSV file saved successfully for Page: 418

# %%
# read csv files and drop duplicates

site_data = pd.read_csv('harakah_daily.csv')
# site_data = site_data.drop_duplicates()
site_data
# Out:
#                                                   Title        Date      Time  \
# 0     Perolehan vaksin: Cubaan ketiga Anwar burukkan PN  2023-02-18  22:09:02
# 1     NPRA, KKM nafi vaksin Covid-19 mengandungi cip ID  2023-02-03  16:27:44
# 2     Tiada laporan kes strok dalam kajian vaksin Co...  2023-01-18  18:55:20
# 3     130 rakyat Singapura tersalah terima dos vaksi...  2022-10-04  10:01:28
# 4                   1.5 juta kanak-kanak belum divaksin  2022-07-28  13:24:14
# ...                                                 ...         ...       ...
# 2503  Kuarantin selaras ajaran Islam, dipraktikkan d...  2020-02-02  00:01:30
# 2504          WEF2020: Apa langkah Malaysia seterusnya?  2020-02-01  19:03:48
# 2505          Virus Corona: Kembali kepada sistem Islam  2020-01-26  17:43:59
# 2506  Penyakit Influenza Virus Corona Wuhan (2019 n-...  2020-01-26  08:46:49
# 2507      Insentif e-Tunai, bimbang keselamatan digital  2020-01-16  06:08:09
#
#                                                    Link Post_Category
# 0     https://harakahdaily.net/index.php/2023/02/18/...      Nasional
# 1     https://harakahdaily.net/index.php/2023/02/03/...      Nasional
# 2     https://harakahdaily.net/index.php/2023/01/18/...        Berita
# 3     https://harakahdaily.net/index.php/2022/10/04/...        Global
# 4     https://harakahdaily.net/index.php/2022/07/28/...      Nasional
# ...                                                 ...           ...
# 2503  https://harakahdaily.net/index.php/2020/02/02/...      Nasional
# 2504  https://harakahdaily.net/index.php/2020/02/01/...        Global
# 2505  https://harakahdaily.net/index.php/2020/01/26/...        Global
# 2506  https://harakahdaily.net/index.php/2020/01/26/...        Berita
# 2507  https://harakahdaily.net/index.php/2020/01/16/...        Berita
#
# [2508 rows x 5 columns]

# %%
# set driver options - do not pop up chrome and disable pop-ups.
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-extensions")
chrome_options.add_argument(f'user-agent":{UserAgent().random}')

# get appropriate drivers for Google Chrome - automatic without downloading driver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), 
                          options=chrome_options)

# %%
def driver_scroll():
    while True:
        # Scroll to the bottom of the page
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait for the page to load
        time.sleep(2)

        # Check if we have reached the bottom of the page
        scroll_position = driver.execute_script("return window.pageYOffset;")
        page_height = driver.execute_script("return document.body.scrollHeight;")
        
        # The position for the end of page, if it is reached, quit browser
        # page_height > scroll_height also work
        if (page_height > scroll_position):
            break

# %%
# find p tags and combine into one article 
article_text = []
for url, link_index in zip(site_data['Link'], range(len(site_data['Link']))):
    print('Processing link: ',link_index)
    driver.get(url)

    driver_scroll()
    page_source = driver.page_source
    
    soup_article = BeautifulSoup(page_source, 'html.parser')
    article_paragraphs = soup_article.find_all('p')
    combined_article = ''
    
    for p in article_paragraphs:
        combined_article += p.get_text()
    article_text.append(combined_article)
    print('Obtained article text for link: ',link_index)
# Out:
# Processing link:  0
# Obtained article text for link:  0
# Processing link:  1
# Obtained article text for link:  1
# Processing link:  2
# Obtained article text for link:  2
# Processing link:  3
# Obtained article text for link:  3
# Processing link:  4
# Obtained article text for link:  4
# Processing link:  5
# Obtained article text for link:  5
# Processing link:  6
# Obtained article text for link:  6
# Processing link:  7
# Obtained article text for link:  7
# Processing link:  8
# Obtained article text for link:  8
# Processing link:  9
# Obtained article text for link:  9
# Processing link:  10
# Obtained article text for link:  10
# Processing link:  11
# Obtained article text for link:  11
# Processing link:  12
# Obtained article text for link:  12
# Processing link:  13
# Obtained article text for link:  13
# Processing link:  14
# Obtained article text for link:  14
# Processing link:  15
# Obtained article text for link:  15
# Processing link:  16
# Obtained article text for link:  16
# Processing link:  17
# Obtained article text for link:  17
# Processing link:  18
# Obtained article text for link:  18
# Processing link:  19
# Obtained article text for link:  19
# Processing link:  20
# Obtained article text for link:  20
# Processing link:  21
# Obtained article text for link:  21
# Processing link:  22
# Obtained article text for link:  22
# Processing link:  23
# Obtained article text for link:  23
# Processing link:  24
# Obtained article text for link:  24
# Processing link:  25
# Obtained article text for link:  25
# Processing link:  26
# Obtained article text for link:  26
# Processing link:  27
# Obtained article text for link:  27
# Processing link:  28
# Obtained article text for link:  28
# Processing link:  29
# Obtained article text for link:  29
# Processing link:  30
# Obtained article text for link:  30
# Processing link:  31
# Obtained article text for link:  31
# Processing link:  32
# Obtained article text for link:  32
# Processing link:  33
# Obtained article text for link:  33
# Processing link:  34
# Obtained article text for link:  34
# Processing link:  35
# Obtained article text for link:  35
# Processing link:  36
# Obtained article text for link:  36
# Processing link:  37
# Obtained article text for link:  37
# Processing link:  38
# Obtained article text for link:  38
# Processing link:  39
# Obtained article text for link:  39
# Processing link:  40
# Obtained article text for link:  40
# Processing link:  41
# Obtained article text for link:  41
# Processing link:  42
# Obtained article text for link:  42
# Processing link:  43
# Obtained article text for link:  43
# Processing link:  44
# Obtained article text for link:  44
# Processing link:  45
# Obtained article text for link:  45
# Processing link:  46
# Obtained article text for link:  46
# Processing link:  47
# Obtained article text for link:  47
# Processing link:  48
# Obtained article text for link:  48
# Processing link:  49
# Obtained article text for link:  49
# Processing link:  50
# Obtained article text for link:  50
# Processing link:  51
# Obtained article text for link:  51
# Processing link:  52
# Obtained article text for link:  52
# Processing link:  53
# Obtained article text for link:  53
# Processing link:  54
# Obtained article text for link:  54
# Processing link:  55
# Obtained article text for link:  55
# Processing link:  56
# Obtained article text for link:  56
# Processing link:  57
# Obtained article text for link:  57
# Processing link:  58
# Obtained article text for link:  58
# Processing link:  59
# Obtained article text for link:  59
# Processing link:  60
# Obtained article text for link:  60
# Processing link:  61
# Obtained article text for link:  61
# Processing link:  62
# Obtained article text for link:  62
# Processing link:  63
# Obtained article text for link:  63
# Processing link:  64
# Obtained article text for link:  64
# Processing link:  65
# Obtained article text for link:  65
# Processing link:  66
# Obtained article text for link:  66
# Processing link:  67
# Obtained article text for link:  67
# Processing link:  68
# Obtained article text for link:  68
# Processing link:  69
# Obtained article text for link:  69
# Processing link:  70
# Obtained article text for link:  70
# Processing link:  71
# Obtained article text for link:  71
# Processing link:  72
# Obtained article text for link:  72
# Processing link:  73
# Obtained article text for link:  73
# Processing link:  74
# Obtained article text for link:  74
# Processing link:  75
# Obtained article text for link:  75
# Processing link:  76
# Obtained article text for link:  76
# Processing link:  77
# Obtained article text for link:  77
# Processing link:  78
# Obtained article text for link:  78
# Processing link:  79
# Obtained article text for link:  79
# Processing link:  80
# Obtained article text for link:  80
# Processing link:  81
# Obtained article text for link:  81
# Processing link:  82
# Obtained article text for link:  82
# Processing link:  83
# Obtained article text for link:  83
# Processing link:  84
# Obtained article text for link:  84
# Processing link:  85
# Obtained article text for link:  85
# Processing link:  86
# Obtained article text for link:  86
# Processing link:  87
# Obtained article text for link:  87
# Processing link:  88
# Obtained article text for link:  88
# Processing link:  89
# Obtained article text for link:  89
# Processing link:  90
# Obtained article text for link:  90
# Processing link:  91
# Obtained article text for link:  91
# Processing link:  92
# Obtained article text for link:  92
# Processing link:  93
# Obtained article text for link:  93
# Processing link:  94
# Obtained article text for link:  94
# Processing link:  95
# Obtained article text for link:  95
# Processing link:  96
# Obtained article text for link:  96
# Processing link:  97
# Obtained article text for link:  97
# Processing link:  98
# Obtained article text for link:  98
# Processing link:  99
# Obtained article text for link:  99
# Processing link:  100
# Obtained article text for link:  100
# Processing link:  101
# Obtained article text for link:  101
# Processing link:  102
# Obtained article text for link:  102
# Processing link:  103
# Obtained article text for link:  103
# Processing link:  104
# Obtained article text for link:  104
# Processing link:  105
# Obtained article text for link:  105
# Processing link:  106
# Obtained article text for link:  106
# Processing link:  107
# Obtained article text for link:  107
# Processing link:  108
# Obtained article text for link:  108
# Processing link:  109
# Obtained article text for link:  109
# Processing link:  110
# Obtained article text for link:  110
# Processing link:  111
# Obtained article text for link:  111
# Processing link:  112
# Obtained article text for link:  112
# Processing link:  113
# Obtained article text for link:  113
# Processing link:  114
# Obtained article text for link:  114
# Processing link:  115
# Obtained article text for link:  115
# Processing link:  116
# Obtained article text for link:  116
# Processing link:  117
# Obtained article text for link:  117
# Processing link:  118
# Obtained article text for link:  118
# Processing link:  119
# Obtained article text for link:  119
# Processing link:  120
# Obtained article text for link:  120
# Processing link:  121
# Obtained article text for link:  121
# Processing link:  122
# Obtained article text for link:  122
# Processing link:  123
# Obtained article text for link:  123
# Processing link:  124
# Obtained article text for link:  124
# Processing link:  125
# Obtained article text for link:  125
# Processing link:  126
# Obtained article text for link:  126
# Processing link:  127
# Obtained article text for link:  127
# Processing link:  128
# Obtained article text for link:  128
# Processing link:  129
# Obtained article text for link:  129
# Processing link:  130
# Obtained article text for link:  130
# Processing link:  131
# Obtained article text for link:  131
# Processing link:  132
# Obtained article text for link:  132
# Processing link:  133
# Obtained article text for link:  133
# Processing link:  134
# Obtained article text for link:  134
# Processing link:  135
# Obtained article text for link:  135
# Processing link:  136
# Obtained article text for link:  136
# Processing link:  137
# Obtained article text for link:  137
# Processing link:  138
# Obtained article text for link:  138
# Processing link:  139
# Obtained article text for link:  139
# Processing link:  140
# Obtained article text for link:  140
# Processing link:  141
# Obtained article text for link:  141
# Processing link:  142
# Obtained article text for link:  142
# Processing link:  143
# Obtained article text for link:  143
# Processing link:  144
# Obtained article text for link:  144
# Processing link:  145
# Obtained article text for link:  145
# Processing link:  146
# Obtained article text for link:  146
# Processing link:  147
# Obtained article text for link:  147
# Processing link:  148
# Obtained article text for link:  148
# Processing link:  149
# Obtained article text for link:  149
# Processing link:  150
# Obtained article text for link:  150
# Processing link:  151
# Obtained article text for link:  151
# Processing link:  152
# Obtained article text for link:  152
# Processing link:  153
# Obtained article text for link:  153
# Processing link:  154
# Obtained article text for link:  154
# Processing link:  155
# Obtained article text for link:  155
# Processing link:  156
# Obtained article text for link:  156
# Processing link:  157
# Obtained article text for link:  157
# Processing link:  158
# Obtained article text for link:  158
# Processing link:  159
# Obtained article text for link:  159
# Processing link:  160
# Obtained article text for link:  160
# Processing link:  161
# Obtained article text for link:  161
# Processing link:  162
# Obtained article text for link:  162
# Processing link:  163
# Obtained article text for link:  163
# Processing link:  164
# Obtained article text for link:  164
# Processing link:  165
# Obtained article text for link:  165
# Processing link:  166
# Obtained article text for link:  166
# Processing link:  167
# Obtained article text for link:  167
# Processing link:  168
# Obtained article text for link:  168
# Processing link:  169
# Obtained article text for link:  169
# Processing link:  170
# Obtained article text for link:  170
# Processing link:  171
# Obtained article text for link:  171
# Processing link:  172
# Obtained article text for link:  172
# Processing link:  173
# Obtained article text for link:  173
# Processing link:  174
# Obtained article text for link:  174
# Processing link:  175
# Obtained article text for link:  175
# Processing link:  176
# Obtained article text for link:  176
# Processing link:  177
# Obtained article text for link:  177
# Processing link:  178
# Obtained article text for link:  178
# Processing link:  179
# Obtained article text for link:  179
# Processing link:  180
# Obtained article text for link:  180
# Processing link:  181
# Obtained article text for link:  181
# Processing link:  182
# Obtained article text for link:  182
# Processing link:  183
# Obtained article text for link:  183
# Processing link:  184
# Obtained article text for link:  184
# Processing link:  185
# Obtained article text for link:  185
# Processing link:  186
# Obtained article text for link:  186
# Processing link:  187
# Obtained article text for link:  187
# Processing link:  188
# Obtained article text for link:  188
# Processing link:  189
# Obtained article text for link:  189
# Processing link:  190
# Obtained article text for link:  190
# Processing link:  191
# Obtained article text for link:  191
# Processing link:  192
# Obtained article text for link:  192
# Processing link:  193
# Obtained article text for link:  193
# Processing link:  194
# Obtained article text for link:  194
# Processing link:  195
# Obtained article text for link:  195
# Processing link:  196
# Obtained article text for link:  196
# Processing link:  197
# Obtained article text for link:  197
# Processing link:  198
# Obtained article text for link:  198
# Processing link:  199
# Obtained article text for link:  199
# Processing link:  200
# Obtained article text for link:  200
# Processing link:  201
# Obtained article text for link:  201
# Processing link:  202
# Obtained article text for link:  202
# Processing link:  203
# Obtained article text for link:  203
# Processing link:  204
# Obtained article text for link:  204
# Processing link:  205
# Obtained article text for link:  205
# Processing link:  206
# Obtained article text for link:  206
# Processing link:  207
# Obtained article text for link:  207
# Processing link:  208
# Obtained article text for link:  208
# Processing link:  209
# Obtained article text for link:  209
# Processing link:  210
# Obtained article text for link:  210
# Processing link:  211
# Obtained article text for link:  211
# Processing link:  212
# Obtained article text for link:  212
# Processing link:  213
# Obtained article text for link:  213
# Processing link:  214
# Obtained article text for link:  214
# Processing link:  215
# Obtained article text for link:  215
# Processing link:  216
# Obtained article text for link:  216
# Processing link:  217
# Obtained article text for link:  217
# Processing link:  218
# Obtained article text for link:  218
# Processing link:  219
# Obtained article text for link:  219
# Processing link:  220
# Obtained article text for link:  220
# Processing link:  221
# Obtained article text for link:  221
# Processing link:  222
# Obtained article text for link:  222
# Processing link:  223
# Obtained article text for link:  223
# Processing link:  224
# Obtained article text for link:  224
# Processing link:  225
# Obtained article text for link:  225
# Processing link:  226
# Obtained article text for link:  226
# Processing link:  227
# Obtained article text for link:  227
# Processing link:  228
# Obtained article text for link:  228
# Processing link:  229
# Obtained article text for link:  229
# Processing link:  230
# Obtained article text for link:  230
# Processing link:  231
# Obtained article text for link:  231
# Processing link:  232
# Obtained article text for link:  232
# Processing link:  233
# Obtained article text for link:  233
# Processing link:  234
# Obtained article text for link:  234
# Processing link:  235
# Obtained article text for link:  235
# Processing link:  236
# Obtained article text for link:  236
# Processing link:  237
# Obtained article text for link:  237
# Processing link:  238
# Obtained article text for link:  238
# Processing link:  239
# Obtained article text for link:  239
# Processing link:  240
# Obtained article text for link:  240
# Processing link:  241
# Obtained article text for link:  241
# Processing link:  242
# Obtained article text for link:  242
# Processing link:  243
# Obtained article text for link:  243
# Processing link:  244
# Obtained article text for link:  244
# Processing link:  245
# Obtained article text for link:  245
# Processing link:  246
# Obtained article text for link:  246
# Processing link:  247
# Obtained article text for link:  247
# Processing link:  248
# Obtained article text for link:  248
# Processing link:  249
# Obtained article text for link:  249
# Processing link:  250
# Obtained article text for link:  250
# Processing link:  251
# Obtained article text for link:  251
# Processing link:  252
# Obtained article text for link:  252
# Processing link:  253
# Obtained article text for link:  253
# Processing link:  254
# Obtained article text for link:  254
# Processing link:  255
# Obtained article text for link:  255
# Processing link:  256
# Obtained article text for link:  256
# Processing link:  257
# Obtained article text for link:  257
# Processing link:  258
# Obtained article text for link:  258
# Processing link:  259
# Obtained article text for link:  259
# Processing link:  260
# Obtained article text for link:  260
# Processing link:  261
# Obtained article text for link:  261
# Processing link:  262
# Obtained article text for link:  262
# Processing link:  263
# Obtained article text for link:  263
# Processing link:  264
# Obtained article text for link:  264
# Processing link:  265
# Obtained article text for link:  265
# Processing link:  266
# Obtained article text for link:  266
# Processing link:  267
# Obtained article text for link:  267
# Processing link:  268
# Obtained article text for link:  268
# Processing link:  269
# Obtained article text for link:  269
# Processing link:  270
# Obtained article text for link:  270
# Processing link:  271
# Obtained article text for link:  271
# Processing link:  272
# Obtained article text for link:  272
# Processing link:  273
# Obtained article text for link:  273
# Processing link:  274
# Obtained article text for link:  274
# Processing link:  275
# Obtained article text for link:  275
# Processing link:  276
# Obtained article text for link:  276
# Processing link:  277
# Obtained article text for link:  277
# Processing link:  278
# Obtained article text for link:  278
# Processing link:  279
# Obtained article text for link:  279
# Processing link:  280
# Obtained article text for link:  280
# Processing link:  281
# Obtained article text for link:  281
# Processing link:  282
# Obtained article text for link:  282
# Processing link:  283
# Obtained article text for link:  283
# Processing link:  284
# Obtained article text for link:  284
# Processing link:  285
# Obtained article text for link:  285
# Processing link:  286
# Obtained article text for link:  286
# Processing link:  287
# Obtained article text for link:  287
# Processing link:  288
# Obtained article text for link:  288
# Processing link:  289
# Obtained article text for link:  289
# Processing link:  290
# Obtained article text for link:  290
# Processing link:  291
# Obtained article text for link:  291
# Processing link:  292
# Obtained article text for link:  292
# Processing link:  293
# Obtained article text for link:  293
# Processing link:  294
# Obtained article text for link:  294
# Processing link:  295
# Obtained article text for link:  295
# Processing link:  296
# Obtained article text for link:  296
# Processing link:  297
# Obtained article text for link:  297
# Processing link:  298
# Obtained article text for link:  298
# Processing link:  299
# Obtained article text for link:  299
# Processing link:  300
# Obtained article text for link:  300
# Processing link:  301
# Obtained article text for link:  301
# Processing link:  302
# Obtained article text for link:  302
# Processing link:  303
# Obtained article text for link:  303
# Processing link:  304
# Obtained article text for link:  304
# Processing link:  305
# Obtained article text for link:  305
# Processing link:  306
# Obtained article text for link:  306
# Processing link:  307
# Obtained article text for link:  307
# Processing link:  308
# Obtained article text for link:  308
# Processing link:  309
# Obtained article text for link:  309
# Processing link:  310
# Obtained article text for link:  310
# Processing link:  311
# Obtained article text for link:  311
# Processing link:  312
# Obtained article text for link:  312
# Processing link:  313
# Obtained article text for link:  313
# Processing link:  314
# Obtained article text for link:  314
# Processing link:  315
# Obtained article text for link:  315
# Processing link:  316
# Obtained article text for link:  316
# Processing link:  317
# Obtained article text for link:  317
# Processing link:  318
# Obtained article text for link:  318
# Processing link:  319
# Obtained article text for link:  319
# Processing link:  320
# Obtained article text for link:  320
# Processing link:  321
# Obtained article text for link:  321
# Processing link:  322
# Obtained article text for link:  322
# Processing link:  323
# Obtained article text for link:  323
# Processing link:  324
# Obtained article text for link:  324
# Processing link:  325
# Obtained article text for link:  325
# Processing link:  326
# Obtained article text for link:  326
# Processing link:  327
# Obtained article text for link:  327
# Processing link:  328
# Obtained article text for link:  328
# Processing link:  329
# Obtained article text for link:  329
# Processing link:  330
# Obtained article text for link:  330
# Processing link:  331
# Obtained article text for link:  331
# Processing link:  332
# Obtained article text for link:  332
# Processing link:  333
# Obtained article text for link:  333
# Processing link:  334
# Obtained article text for link:  334
# Processing link:  335
# Obtained article text for link:  335
# Processing link:  336
# Obtained article text for link:  336
# Processing link:  337
# Obtained article text for link:  337
# Processing link:  338
# Obtained article text for link:  338
# Processing link:  339
# Obtained article text for link:  339
# Processing link:  340
# Obtained article text for link:  340
# Processing link:  341
# Obtained article text for link:  341
# Processing link:  342
# Obtained article text for link:  342
# Processing link:  343
# Obtained article text for link:  343
# Processing link:  344
# Obtained article text for link:  344
# Processing link:  345
# Obtained article text for link:  345
# Processing link:  346
# Obtained article text for link:  346
# Processing link:  347
# Obtained article text for link:  347
# Processing link:  348
# Obtained article text for link:  348
# Processing link:  349
# Obtained article text for link:  349
# Processing link:  350
# Obtained article text for link:  350
# Processing link:  351
# Obtained article text for link:  351
# Processing link:  352
# Obtained article text for link:  352
# Processing link:  353
# Obtained article text for link:  353
# Processing link:  354
# Obtained article text for link:  354
# Processing link:  355
# Obtained article text for link:  355
# Processing link:  356
# Obtained article text for link:  356
# Processing link:  357
# Obtained article text for link:  357
# Processing link:  358
# Obtained article text for link:  358
# Processing link:  359
# Obtained article text for link:  359
# Processing link:  360
# Obtained article text for link:  360
# Processing link:  361
# Obtained article text for link:  361
# Processing link:  362
# Obtained article text for link:  362
# Processing link:  363
# Obtained article text for link:  363
# Processing link:  364
# Obtained article text for link:  364
# Processing link:  365
# Obtained article text for link:  365
# Processing link:  366
# Obtained article text for link:  366
# Processing link:  367
# Obtained article text for link:  367
# Processing link:  368
# Obtained article text for link:  368
# Processing link:  369
# Obtained article text for link:  369
# Processing link:  370
# Obtained article text for link:  370
# Processing link:  371
# Obtained article text for link:  371
# Processing link:  372
# Obtained article text for link:  372
# Processing link:  373
# Obtained article text for link:  373
# Processing link:  374
# Obtained article text for link:  374
# Processing link:  375
# Obtained article text for link:  375
# Processing link:  376
# Obtained article text for link:  376
# Processing link:  377
# Obtained article text for link:  377
# Processing link:  378
# Obtained article text for link:  378
# Processing link:  379
# Obtained article text for link:  379
# Processing link:  380
# Obtained article text for link:  380
# Processing link:  381
# Obtained article text for link:  381
# Processing link:  382
# Obtained article text for link:  382
# Processing link:  383
# Obtained article text for link:  383
# Processing link:  384
# Obtained article text for link:  384
# Processing link:  385
# Obtained article text for link:  385
# Processing link:  386
# Obtained article text for link:  386
# Processing link:  387
# Obtained article text for link:  387
# Processing link:  388
# Obtained article text for link:  388
# Processing link:  389
# Obtained article text for link:  389
# Processing link:  390
# Obtained article text for link:  390
# Processing link:  391
# Obtained article text for link:  391
# Processing link:  392
# Obtained article text for link:  392
# Processing link:  393
# Obtained article text for link:  393
# Processing link:  394
# Obtained article text for link:  394
# Processing link:  395
# Obtained article text for link:  395
# Processing link:  396
# Obtained article text for link:  396
# Processing link:  397
# Obtained article text for link:  397
# Processing link:  398
# Obtained article text for link:  398
# Processing link:  399
# Obtained article text for link:  399
# Processing link:  400
# Obtained article text for link:  400
# Processing link:  401
# Obtained article text for link:  401
# Processing link:  402
# Obtained article text for link:  402
# Processing link:  403
# Obtained article text for link:  403
# Processing link:  404
# Obtained article text for link:  404
# Processing link:  405
# Obtained article text for link:  405
# Processing link:  406
# Obtained article text for link:  406
# Processing link:  407
# Obtained article text for link:  407
# Processing link:  408
# Obtained article text for link:  408
# Processing link:  409
# Obtained article text for link:  409
# Processing link:  410
# Obtained article text for link:  410
# Processing link:  411
# Obtained article text for link:  411
# Processing link:  412
# Obtained article text for link:  412
# Processing link:  413
# Obtained article text for link:  413
# Processing link:  414
# Obtained article text for link:  414
# Processing link:  415
# Obtained article text for link:  415
# Processing link:  416
# Obtained article text for link:  416
# Processing link:  417
# Obtained article text for link:  417
# Processing link:  418
# Obtained article text for link:  418
# Processing link:  419
# Obtained article text for link:  419
# Processing link:  420
# Obtained article text for link:  420
# Processing link:  421
# Obtained article text for link:  421
# Processing link:  422
# Obtained article text for link:  422
# Processing link:  423
# Obtained article text for link:  423
# Processing link:  424
# Obtained article text for link:  424
# Processing link:  425
# Obtained article text for link:  425
# Processing link:  426
# Obtained article text for link:  426
# Processing link:  427
# Obtained article text for link:  427
# Processing link:  428
# Obtained article text for link:  428
# Processing link:  429
# Obtained article text for link:  429
# Processing link:  430
# Obtained article text for link:  430
# Processing link:  431
# Obtained article text for link:  431
# Processing link:  432
# Obtained article text for link:  432
# Processing link:  433
# Obtained article text for link:  433
# Processing link:  434
# Obtained article text for link:  434
# Processing link:  435
# Obtained article text for link:  435
# Processing link:  436
# Obtained article text for link:  436
# Processing link:  437
# Obtained article text for link:  437
# Processing link:  438
# Obtained article text for link:  438
# Processing link:  439
# Obtained article text for link:  439
# Processing link:  440
# Obtained article text for link:  440
# Processing link:  441
# Obtained article text for link:  441
# Processing link:  442
# Obtained article text for link:  442
# Processing link:  443
# Obtained article text for link:  443
# Processing link:  444
# Obtained article text for link:  444
# Processing link:  445
# Obtained article text for link:  445
# Processing link:  446
# Obtained article text for link:  446
# Processing link:  447
# Obtained article text for link:  447
# Processing link:  448
# Obtained article text for link:  448
# Processing link:  449
# Obtained article text for link:  449
# Processing link:  450
# Obtained article text for link:  450
# Processing link:  451
# Obtained article text for link:  451
# Processing link:  452
# Obtained article text for link:  452
# Processing link:  453
# Obtained article text for link:  453
# Processing link:  454
# Obtained article text for link:  454
# Processing link:  455
# Obtained article text for link:  455
# Processing link:  456
# Obtained article text for link:  456
# Processing link:  457
# Obtained article text for link:  457
# Processing link:  458
# Obtained article text for link:  458
# Processing link:  459
# Obtained article text for link:  459
# Processing link:  460
# Obtained article text for link:  460
# Processing link:  461
# Obtained article text for link:  461
# Processing link:  462
# Obtained article text for link:  462
# Processing link:  463
# Obtained article text for link:  463
# Processing link:  464
# Obtained article text for link:  464
# Processing link:  465
# Obtained article text for link:  465
# Processing link:  466
# Obtained article text for link:  466
# Processing link:  467
# Obtained article text for link:  467
# Processing link:  468
# Obtained article text for link:  468
# Processing link:  469
# Obtained article text for link:  469
# Processing link:  470
# Obtained article text for link:  470
# Processing link:  471
# Obtained article text for link:  471
# Processing link:  472
# Obtained article text for link:  472
# Processing link:  473
# Obtained article text for link:  473
# Processing link:  474
# Obtained article text for link:  474
# Processing link:  475
# Obtained article text for link:  475
# Processing link:  476
# Obtained article text for link:  476
# Processing link:  477
# Obtained article text for link:  477
# Processing link:  478
# Obtained article text for link:  478
# Processing link:  479
# Obtained article text for link:  479
# Processing link:  480
# Obtained article text for link:  480
# Processing link:  481
# Obtained article text for link:  481
# Processing link:  482
# Obtained article text for link:  482
# Processing link:  483
# Obtained article text for link:  483
# Processing link:  484
# Obtained article text for link:  484
# Processing link:  485
# Obtained article text for link:  485
# Processing link:  486
# Obtained article text for link:  486
# Processing link:  487
# Obtained article text for link:  487
# Processing link:  488
# Obtained article text for link:  488
# Processing link:  489
# Obtained article text for link:  489
# Processing link:  490
# Obtained article text for link:  490
# Processing link:  491
# Obtained article text for link:  491
# Processing link:  492
# Obtained article text for link:  492
# Processing link:  493
# Obtained article text for link:  493
# Processing link:  494
# Obtained article text for link:  494
# Processing link:  495
# Obtained article text for link:  495
# Processing link:  496
# Obtained article text for link:  496
# Processing link:  497
# Obtained article text for link:  497
# Processing link:  498
# Obtained article text for link:  498
# Processing link:  499
# Obtained article text for link:  499
# Processing link:  500
# Obtained article text for link:  500
# Processing link:  501
# Obtained article text for link:  501
# Processing link:  502
# Obtained article text for link:  502
# Processing link:  503
# Obtained article text for link:  503
# Processing link:  504
# Obtained article text for link:  504
# Processing link:  505
# Obtained article text for link:  505
# Processing link:  506
# Obtained article text for link:  506
# Processing link:  507
# Obtained article text for link:  507
# Processing link:  508
# Obtained article text for link:  508
# Processing link:  509
# Obtained article text for link:  509
# Processing link:  510
# Obtained article text for link:  510
# Processing link:  511
# Obtained article text for link:  511
# Processing link:  512
# Obtained article text for link:  512
# Processing link:  513
# Obtained article text for link:  513
# Processing link:  514
# Obtained article text for link:  514
# Processing link:  515
# Obtained article text for link:  515
# Processing link:  516
# Obtained article text for link:  516
# Processing link:  517
# Obtained article text for link:  517
# Processing link:  518
# Obtained article text for link:  518
# Processing link:  519
# Obtained article text for link:  519
# Processing link:  520
# Obtained article text for link:  520
# Processing link:  521
# Obtained article text for link:  521
# Processing link:  522
# Obtained article text for link:  522
# Processing link:  523
# Obtained article text for link:  523
# Processing link:  524
# Obtained article text for link:  524
# Processing link:  525
# Obtained article text for link:  525
# Processing link:  526
# Obtained article text for link:  526
# Processing link:  527
# Obtained article text for link:  527
# Processing link:  528
# Obtained article text for link:  528
# Processing link:  529
# Obtained article text for link:  529
# Processing link:  530
# Obtained article text for link:  530
# Processing link:  531
# Obtained article text for link:  531
# Processing link:  532
# Obtained article text for link:  532
# Processing link:  533
# Obtained article text for link:  533
# Processing link:  534
# Obtained article text for link:  534
# Processing link:  535
# Obtained article text for link:  535
# Processing link:  536
# Obtained article text for link:  536
# Processing link:  537
# Obtained article text for link:  537
# Processing link:  538
# Obtained article text for link:  538
# Processing link:  539
# Obtained article text for link:  539
# Processing link:  540
# Obtained article text for link:  540
# Processing link:  541
# Obtained article text for link:  541
# Processing link:  542
# Obtained article text for link:  542
# Processing link:  543
# Obtained article text for link:  543
# Processing link:  544
# Obtained article text for link:  544
# Processing link:  545
# Obtained article text for link:  545
# Processing link:  546
# Obtained article text for link:  546
# Processing link:  547
# Obtained article text for link:  547
# Processing link:  548
# Obtained article text for link:  548
# Processing link:  549
# Obtained article text for link:  549
# Processing link:  550
# Obtained article text for link:  550
# Processing link:  551
# Obtained article text for link:  551
# Processing link:  552
# Obtained article text for link:  552
# Processing link:  553
# Obtained article text for link:  553
# Processing link:  554
# Obtained article text for link:  554
# Processing link:  555
# Obtained article text for link:  555
# Processing link:  556
# Obtained article text for link:  556
# Processing link:  557
# Obtained article text for link:  557
# Processing link:  558
# Obtained article text for link:  558
# Processing link:  559
# Obtained article text for link:  559
# Processing link:  560
# Obtained article text for link:  560
# Processing link:  561
# Obtained article text for link:  561
# Processing link:  562
# Obtained article text for link:  562
# Processing link:  563
# Obtained article text for link:  563
# Processing link:  564
# Obtained article text for link:  564
# Processing link:  565
# Obtained article text for link:  565
# Processing link:  566
# Obtained article text for link:  566
# Processing link:  567
# Obtained article text for link:  567
# Processing link:  568
# Obtained article text for link:  568
# Processing link:  569
# Obtained article text for link:  569
# Processing link:  570
# Obtained article text for link:  570
# Processing link:  571
# Obtained article text for link:  571
# Processing link:  572
# Obtained article text for link:  572
# Processing link:  573
# Obtained article text for link:  573
# Processing link:  574
# Obtained article text for link:  574
# Processing link:  575
# Obtained article text for link:  575
# Processing link:  576
# Obtained article text for link:  576
# Processing link:  577
# Obtained article text for link:  577
# Processing link:  578
# Obtained article text for link:  578
# Processing link:  579
# Obtained article text for link:  579
# Processing link:  580
# Obtained article text for link:  580
# Processing link:  581
# Obtained article text for link:  581
# Processing link:  582
# Obtained article text for link:  582
# Processing link:  583
# Obtained article text for link:  583
# Processing link:  584
# Obtained article text for link:  584
# Processing link:  585
# Obtained article text for link:  585
# Processing link:  586
# Obtained article text for link:  586
# Processing link:  587
# Obtained article text for link:  587
# Processing link:  588
# Obtained article text for link:  588
# Processing link:  589
# Obtained article text for link:  589
# Processing link:  590
# Obtained article text for link:  590
# Processing link:  591
# Obtained article text for link:  591
# Processing link:  592
# Obtained article text for link:  592
# Processing link:  593
# Obtained article text for link:  593
# Processing link:  594
# Obtained article text for link:  594
# Processing link:  595
# Obtained article text for link:  595
# Processing link:  596
# Obtained article text for link:  596
# Processing link:  597
# Obtained article text for link:  597
# Processing link:  598
# Obtained article text for link:  598
# Processing link:  599
# Obtained article text for link:  599
# Processing link:  600
# Obtained article text for link:  600
# Processing link:  601
# Obtained article text for link:  601
# Processing link:  602
# Obtained article text for link:  602
# Processing link:  603
# Obtained article text for link:  603
# Processing link:  604
# Obtained article text for link:  604
# Processing link:  605
# Obtained article text for link:  605
# Processing link:  606
# Obtained article text for link:  606
# Processing link:  607
# Obtained article text for link:  607
# Processing link:  608
# Obtained article text for link:  608
# Processing link:  609
# Obtained article text for link:  609
# Processing link:  610
# Obtained article text for link:  610
# Processing link:  611
# Obtained article text for link:  611
# Processing link:  612
# Obtained article text for link:  612
# Processing link:  613
# Obtained article text for link:  613
# Processing link:  614
# Obtained article text for link:  614
# Processing link:  615
# Obtained article text for link:  615
# Processing link:  616
# Obtained article text for link:  616
# Processing link:  617
# Obtained article text for link:  617
# Processing link:  618
# Obtained article text for link:  618
# Processing link:  619
# Obtained article text for link:  619
# Processing link:  620
# Obtained article text for link:  620
# Processing link:  621
# Obtained article text for link:  621
# Processing link:  622
# Obtained article text for link:  622
# Processing link:  623
# Obtained article text for link:  623
# Processing link:  624
# Obtained article text for link:  624
# Processing link:  625
# Obtained article text for link:  625
# Processing link:  626
# Obtained article text for link:  626
# Processing link:  627
# Obtained article text for link:  627
# Processing link:  628
# Obtained article text for link:  628
# Processing link:  629
# Obtained article text for link:  629
# Processing link:  630
# Obtained article text for link:  630
# Processing link:  631
# Obtained article text for link:  631
# Processing link:  632
# Obtained article text for link:  632
# Processing link:  633
# Obtained article text for link:  633
# Processing link:  634
# Obtained article text for link:  634
# Processing link:  635
# Obtained article text for link:  635
# Processing link:  636
# Obtained article text for link:  636
# Processing link:  637
# Obtained article text for link:  637
# Processing link:  638
# Obtained article text for link:  638
# Processing link:  639
# Obtained article text for link:  639
# Processing link:  640
# Obtained article text for link:  640
# Processing link:  641
# Obtained article text for link:  641
# Processing link:  642
# Obtained article text for link:  642
# Processing link:  643
# Obtained article text for link:  643
# Processing link:  644
# Obtained article text for link:  644
# Processing link:  645
# Obtained article text for link:  645
# Processing link:  646
# Obtained article text for link:  646
# Processing link:  647
# Obtained article text for link:  647
# Processing link:  648
# Obtained article text for link:  648
# Processing link:  649
# Obtained article text for link:  649
# Processing link:  650
# Obtained article text for link:  650
# Processing link:  651
# Obtained article text for link:  651
# Processing link:  652
# Obtained article text for link:  652
# Processing link:  653
# Obtained article text for link:  653
# Processing link:  654
# Obtained article text for link:  654
# Processing link:  655
# Obtained article text for link:  655
# Processing link:  656
# Obtained article text for link:  656
# Processing link:  657
# Obtained article text for link:  657
# Processing link:  658
# Obtained article text for link:  658
# Processing link:  659
# Obtained article text for link:  659
# Processing link:  660
# Obtained article text for link:  660
# Processing link:  661
# Obtained article text for link:  661
# Processing link:  662
# Obtained article text for link:  662
# Processing link:  663
# Obtained article text for link:  663
# Processing link:  664
# Obtained article text for link:  664
# Processing link:  665
# Obtained article text for link:  665
# Processing link:  666
# Obtained article text for link:  666
# Processing link:  667
# Obtained article text for link:  667
# Processing link:  668
# Obtained article text for link:  668
# Processing link:  669
# Obtained article text for link:  669
# Processing link:  670
# Obtained article text for link:  670
# Processing link:  671
# Obtained article text for link:  671
# Processing link:  672
# Obtained article text for link:  672
# Processing link:  673
# Obtained article text for link:  673
# Processing link:  674
# Obtained article text for link:  674
# Processing link:  675
# Obtained article text for link:  675
# Processing link:  676
# Obtained article text for link:  676
# Processing link:  677
# Obtained article text for link:  677
# Processing link:  678
# Obtained article text for link:  678
# Processing link:  679
# Obtained article text for link:  679
# Processing link:  680
# Obtained article text for link:  680
# Processing link:  681
# Obtained article text for link:  681
# Processing link:  682
# Obtained article text for link:  682
# Processing link:  683
# Obtained article text for link:  683
# Processing link:  684
# Obtained article text for link:  684
# Processing link:  685
# Obtained article text for link:  685
# Processing link:  686
# Obtained article text for link:  686
# Processing link:  687
# Obtained article text for link:  687
# Processing link:  688
# Obtained article text for link:  688
# Processing link:  689
# Obtained article text for link:  689
# Processing link:  690
# Obtained article text for link:  690
# Processing link:  691
# Obtained article text for link:  691
# Processing link:  692
# Obtained article text for link:  692
# Processing link:  693
# Obtained article text for link:  693
# Processing link:  694
# Obtained article text for link:  694
# Processing link:  695
# Obtained article text for link:  695
# Processing link:  696
# Obtained article text for link:  696
# Processing link:  697
# Obtained article text for link:  697
# Processing link:  698
# Obtained article text for link:  698
# Processing link:  699
# Obtained article text for link:  699
# Processing link:  700
# Obtained article text for link:  700
# Processing link:  701
# Obtained article text for link:  701
# Processing link:  702
# Obtained article text for link:  702
# Processing link:  703
# Obtained article text for link:  703
# Processing link:  704
# Obtained article text for link:  704
# Processing link:  705
# Obtained article text for link:  705
# Processing link:  706
# Obtained article text for link:  706
# Processing link:  707
# Obtained article text for link:  707
# Processing link:  708
# Obtained article text for link:  708
# Processing link:  709
# Obtained article text for link:  709
# Processing link:  710
# Obtained article text for link:  710
# Processing link:  711
# Obtained article text for link:  711
# Processing link:  712
# Obtained article text for link:  712
# Processing link:  713
# Obtained article text for link:  713
# Processing link:  714
# Obtained article text for link:  714
# Processing link:  715
# Obtained article text for link:  715
# Processing link:  716
# Obtained article text for link:  716
# Processing link:  717
# Obtained article text for link:  717
# Processing link:  718
# Obtained article text for link:  718
# Processing link:  719
# Obtained article text for link:  719
# Processing link:  720
# Obtained article text for link:  720
# Processing link:  721
# Obtained article text for link:  721
# Processing link:  722
# Obtained article text for link:  722
# Processing link:  723
# Obtained article text for link:  723
# Processing link:  724
# Obtained article text for link:  724
# Processing link:  725
# Obtained article text for link:  725
# Processing link:  726
# Obtained article text for link:  726
# Processing link:  727
# Obtained article text for link:  727
# Processing link:  728
# Obtained article text for link:  728
# Processing link:  729
# Obtained article text for link:  729
# Processing link:  730
# Obtained article text for link:  730
# Processing link:  731
# Obtained article text for link:  731
# Processing link:  732
# Obtained article text for link:  732
# Processing link:  733
# Obtained article text for link:  733
# Processing link:  734
# Obtained article text for link:  734
# Processing link:  735
# Obtained article text for link:  735
# Processing link:  736
# Obtained article text for link:  736
# Processing link:  737
# Obtained article text for link:  737
# Processing link:  738
# Obtained article text for link:  738
# Processing link:  739
# Obtained article text for link:  739
# Processing link:  740
# Obtained article text for link:  740
# Processing link:  741
# Obtained article text for link:  741
# Processing link:  742
# Obtained article text for link:  742
# Processing link:  743
# Obtained article text for link:  743
# Processing link:  744
# Obtained article text for link:  744
# Processing link:  745
# Obtained article text for link:  745
# Processing link:  746
# Obtained article text for link:  746
# Processing link:  747
# Obtained article text for link:  747
# Processing link:  748
# Obtained article text for link:  748
# Processing link:  749
# Obtained article text for link:  749
# Processing link:  750
# Obtained article text for link:  750
# Processing link:  751
# Obtained article text for link:  751
# Processing link:  752
# Obtained article text for link:  752
# Processing link:  753
# Obtained article text for link:  753
# Processing link:  754
# Obtained article text for link:  754
# Processing link:  755
# Obtained article text for link:  755
# Processing link:  756
# Obtained article text for link:  756
# Processing link:  757
# Obtained article text for link:  757
# Processing link:  758
# Obtained article text for link:  758
# Processing link:  759
# Obtained article text for link:  759
# Processing link:  760
# Obtained article text for link:  760
# Processing link:  761
# Obtained article text for link:  761
# Processing link:  762
# Obtained article text for link:  762
# Processing link:  763
# Obtained article text for link:  763
# Processing link:  764
# Obtained article text for link:  764
# Processing link:  765
# Obtained article text for link:  765
# Processing link:  766
# Obtained article text for link:  766
# Processing link:  767
# Obtained article text for link:  767
# Processing link:  768
# Obtained article text for link:  768
# Processing link:  769
# Obtained article text for link:  769
# Processing link:  770
# Obtained article text for link:  770
# Processing link:  771
# Obtained article text for link:  771
# Processing link:  772
# Obtained article text for link:  772
# Processing link:  773
# Obtained article text for link:  773
# Processing link:  774
# Obtained article text for link:  774
# Processing link:  775
# Obtained article text for link:  775
# Processing link:  776
# Obtained article text for link:  776
# Processing link:  777
# Obtained article text for link:  777
# Processing link:  778
# Obtained article text for link:  778
# Processing link:  779
# Obtained article text for link:  779
# Processing link:  780
# Obtained article text for link:  780
# Processing link:  781
# Obtained article text for link:  781
# Processing link:  782
# Obtained article text for link:  782
# Processing link:  783
# Obtained article text for link:  783
# Processing link:  784
# Obtained article text for link:  784
# Processing link:  785
# Obtained article text for link:  785
# Processing link:  786
# Obtained article text for link:  786
# Processing link:  787
# Obtained article text for link:  787
# Processing link:  788
# Obtained article text for link:  788
# Processing link:  789
# Obtained article text for link:  789
# Processing link:  790
# Obtained article text for link:  790
# Processing link:  791
# Obtained article text for link:  791
# Processing link:  792
# Obtained article text for link:  792
# Processing link:  793
# Obtained article text for link:  793
# Processing link:  794
# Obtained article text for link:  794
# Processing link:  795
# Obtained article text for link:  795
# Processing link:  796
# Obtained article text for link:  796
# Processing link:  797
# Obtained article text for link:  797
# Processing link:  798
# Obtained article text for link:  798
# Processing link:  799
# Obtained article text for link:  799
# Processing link:  800
# Obtained article text for link:  800
# Processing link:  801
# Obtained article text for link:  801
# Processing link:  802
# Obtained article text for link:  802
# Processing link:  803
# Obtained article text for link:  803
# Processing link:  804
# Obtained article text for link:  804
# Processing link:  805
# Obtained article text for link:  805
# Processing link:  806
# Obtained article text for link:  806
# Processing link:  807
# Obtained article text for link:  807
# Processing link:  808
# Obtained article text for link:  808
# Processing link:  809
# Obtained article text for link:  809
# Processing link:  810
# Obtained article text for link:  810
# Processing link:  811
# Obtained article text for link:  811
# Processing link:  812
# Obtained article text for link:  812
# Processing link:  813
# Obtained article text for link:  813
# Processing link:  814
# Obtained article text for link:  814
# Processing link:  815
# Obtained article text for link:  815
# Processing link:  816
# Obtained article text for link:  816
# ...
# Processing link:  2246
# Obtained article text for link:  2246
# Processing link:  2247
# Obtained article text for link:  2247
# Processing link:  2248
# Obtained article text for link:  2248
# Processing link:  2249
# Obtained article text for link:  2249
# Processing link:  2250
# Obtained article text for link:  2250
# Processing link:  2251
# Obtained article text for link:  2251
# Processing link:  2252
# Obtained article text for link:  2252
# Processing link:  2253
# Obtained article text for link:  2253
# Processing link:  2254
# Obtained article text for link:  2254
# Processing link:  2255
# Obtained article text for link:  2255
# Processing link:  2256
# Obtained article text for link:  2256
# Processing link:  2257
# Obtained article text for link:  2257
# Processing link:  2258
# Obtained article text for link:  2258
# Processing link:  2259
# Obtained article text for link:  2259
# Processing link:  2260
# Obtained article text for link:  2260
# Processing link:  2261
# Obtained article text for link:  2261
# Processing link:  2262
# Obtained article text for link:  2262
# Processing link:  2263
# Obtained article text for link:  2263
# Processing link:  2264
# Obtained article text for link:  2264
# Processing link:  2265
# Obtained article text for link:  2265
# Processing link:  2266
# Obtained article text for link:  2266
# Processing link:  2267
# Obtained article text for link:  2267
# Processing link:  2268
# Obtained article text for link:  2268
# Processing link:  2269
# Obtained article text for link:  2269
# Processing link:  2270
# Obtained article text for link:  2270
# Processing link:  2271
# Obtained article text for link:  2271
# Processing link:  2272
# Obtained article text for link:  2272
# Processing link:  2273
# Obtained article text for link:  2273
# Processing link:  2274
# Obtained article text for link:  2274
# Processing link:  2275
# Obtained article text for link:  2275
# Processing link:  2276
# Obtained article text for link:  2276
# Processing link:  2277
# Obtained article text for link:  2277
# Processing link:  2278
# Obtained article text for link:  2278
# Processing link:  2279
# Obtained article text for link:  2279
# Processing link:  2280
# Obtained article text for link:  2280
# Processing link:  2281
# Obtained article text for link:  2281
# Processing link:  2282
# Obtained article text for link:  2282
# Processing link:  2283
# Obtained article text for link:  2283
# Processing link:  2284
# Obtained article text for link:  2284
# Processing link:  2285
# Obtained article text for link:  2285
# Processing link:  2286
# Obtained article text for link:  2286
# Processing link:  2287
# Obtained article text for link:  2287
# Processing link:  2288
# Obtained article text for link:  2288
# Processing link:  2289
# Obtained article text for link:  2289
# Processing link:  2290
# Obtained article text for link:  2290
# Processing link:  2291
# Obtained article text for link:  2291
# Processing link:  2292
# Obtained article text for link:  2292
# Processing link:  2293
# Obtained article text for link:  2293
# Processing link:  2294
# Obtained article text for link:  2294
# Processing link:  2295
# Obtained article text for link:  2295
# Processing link:  2296
# Obtained article text for link:  2296
# Processing link:  2297
# Obtained article text for link:  2297
# Processing link:  2298
# Obtained article text for link:  2298
# Processing link:  2299
# Obtained article text for link:  2299
# Processing link:  2300
# Obtained article text for link:  2300
# Processing link:  2301
# Obtained article text for link:  2301
# Processing link:  2302
# Obtained article text for link:  2302
# Processing link:  2303
# Obtained article text for link:  2303
# Processing link:  2304
# Obtained article text for link:  2304
# Processing link:  2305
# Obtained article text for link:  2305
# Processing link:  2306
# Obtained article text for link:  2306
# Processing link:  2307
# Obtained article text for link:  2307
# Processing link:  2308
# Obtained article text for link:  2308
# Processing link:  2309
# Obtained article text for link:  2309
# Processing link:  2310
# Obtained article text for link:  2310
# Processing link:  2311
# Obtained article text for link:  2311
# Processing link:  2312
# Obtained article text for link:  2312
# Processing link:  2313
# Obtained article text for link:  2313
# Processing link:  2314
# Obtained article text for link:  2314
# Processing link:  2315
# Obtained article text for link:  2315
# Processing link:  2316
# Obtained article text for link:  2316
# Processing link:  2317
# Obtained article text for link:  2317
# Processing link:  2318
# Obtained article text for link:  2318
# Processing link:  2319
# Obtained article text for link:  2319
# Processing link:  2320
# Obtained article text for link:  2320
# Processing link:  2321
# Obtained article text for link:  2321
# Processing link:  2322
# Obtained article text for link:  2322
# Processing link:  2323
# Obtained article text for link:  2323
# Processing link:  2324
# Obtained article text for link:  2324
# Processing link:  2325
# Obtained article text for link:  2325
# Processing link:  2326
# Obtained article text for link:  2326
# Processing link:  2327
# Obtained article text for link:  2327
# Processing link:  2328
# Obtained article text for link:  2328
# Processing link:  2329
# Obtained article text for link:  2329
# Processing link:  2330
# Obtained article text for link:  2330
# Processing link:  2331
# Obtained article text for link:  2331
# Processing link:  2332
# Obtained article text for link:  2332
# Processing link:  2333
# Obtained article text for link:  2333
# Processing link:  2334
# Obtained article text for link:  2334
# Processing link:  2335
# Obtained article text for link:  2335
# Processing link:  2336
# Obtained article text for link:  2336
# Processing link:  2337
# Obtained article text for link:  2337
# Processing link:  2338
# Obtained article text for link:  2338
# Processing link:  2339
# Obtained article text for link:  2339
# Processing link:  2340
# Obtained article text for link:  2340
# Processing link:  2341
# Obtained article text for link:  2341
# Processing link:  2342
# Obtained article text for link:  2342
# Processing link:  2343
# Obtained article text for link:  2343
# Processing link:  2344
# Obtained article text for link:  2344
# Processing link:  2345
# Obtained article text for link:  2345
# Processing link:  2346
# Obtained article text for link:  2346
# Processing link:  2347
# Obtained article text for link:  2347
# Processing link:  2348
# Obtained article text for link:  2348
# Processing link:  2349
# Obtained article text for link:  2349
# Processing link:  2350
# Obtained article text for link:  2350
# Processing link:  2351
# Obtained article text for link:  2351
# Processing link:  2352
# Obtained article text for link:  2352
# Processing link:  2353
# Obtained article text for link:  2353
# Processing link:  2354
# Obtained article text for link:  2354
# Processing link:  2355
# Obtained article text for link:  2355
# Processing link:  2356
# Obtained article text for link:  2356
# Processing link:  2357
# Obtained article text for link:  2357
# Processing link:  2358
# Obtained article text for link:  2358
# Processing link:  2359
# Obtained article text for link:  2359
# Processing link:  2360
# Obtained article text for link:  2360
# Processing link:  2361
# Obtained article text for link:  2361
# Processing link:  2362
# Obtained article text for link:  2362
# Processing link:  2363
# Obtained article text for link:  2363
# Processing link:  2364
# Obtained article text for link:  2364
# Processing link:  2365
# Obtained article text for link:  2365
# Processing link:  2366
# Obtained article text for link:  2366
# Processing link:  2367
# Obtained article text for link:  2367
# Processing link:  2368
# Obtained article text for link:  2368
# Processing link:  2369
# Obtained article text for link:  2369
# Processing link:  2370
# Obtained article text for link:  2370
# Processing link:  2371
# Obtained article text for link:  2371
# Processing link:  2372
# Obtained article text for link:  2372
# Processing link:  2373
# Obtained article text for link:  2373
# Processing link:  2374
# Obtained article text for link:  2374
# Processing link:  2375
# Obtained article text for link:  2375
# Processing link:  2376
# Obtained article text for link:  2376
# Processing link:  2377
# Obtained article text for link:  2377
# Processing link:  2378
# Obtained article text for link:  2378
# Processing link:  2379
# Obtained article text for link:  2379
# Processing link:  2380
# Obtained article text for link:  2380
# Processing link:  2381
# Obtained article text for link:  2381
# Processing link:  2382
# Obtained article text for link:  2382
# Processing link:  2383
# Obtained article text for link:  2383
# Processing link:  2384
# Obtained article text for link:  2384
# Processing link:  2385
# Obtained article text for link:  2385
# Processing link:  2386
# Obtained article text for link:  2386
# Processing link:  2387
# Obtained article text for link:  2387
# Processing link:  2388
# Obtained article text for link:  2388
# Processing link:  2389
# Obtained article text for link:  2389
# Processing link:  2390
# Obtained article text for link:  2390
# Processing link:  2391
# Obtained article text for link:  2391
# Processing link:  2392
# Obtained article text for link:  2392
# Processing link:  2393
# Obtained article text for link:  2393
# Processing link:  2394
# Obtained article text for link:  2394
# Processing link:  2395
# Obtained article text for link:  2395
# Processing link:  2396
# Obtained article text for link:  2396
# Processing link:  2397
# Obtained article text for link:  2397
# Processing link:  2398
# Obtained article text for link:  2398
# Processing link:  2399
# Obtained article text for link:  2399
# Processing link:  2400
# Obtained article text for link:  2400
# Processing link:  2401
# Obtained article text for link:  2401
# Processing link:  2402
# Obtained article text for link:  2402
# Processing link:  2403
# Obtained article text for link:  2403
# Processing link:  2404
# Obtained article text for link:  2404
# Processing link:  2405
# Obtained article text for link:  2405
# Processing link:  2406
# Obtained article text for link:  2406
# Processing link:  2407
# Obtained article text for link:  2407
# Processing link:  2408
# Obtained article text for link:  2408
# Processing link:  2409
# Obtained article text for link:  2409
# Processing link:  2410
# Obtained article text for link:  2410
# Processing link:  2411
# Obtained article text for link:  2411
# Processing link:  2412
# Obtained article text for link:  2412
# Processing link:  2413
# Obtained article text for link:  2413
# Processing link:  2414
# Obtained article text for link:  2414
# Processing link:  2415
# Obtained article text for link:  2415
# Processing link:  2416
# Obtained article text for link:  2416
# Processing link:  2417
# Obtained article text for link:  2417
# Processing link:  2418
# Obtained article text for link:  2418
# Processing link:  2419
# Obtained article text for link:  2419
# Processing link:  2420
# Obtained article text for link:  2420
# Processing link:  2421
# Obtained article text for link:  2421
# Processing link:  2422
# Obtained article text for link:  2422
# Processing link:  2423
# Obtained article text for link:  2423
# Processing link:  2424
# Obtained article text for link:  2424
# Processing link:  2425
# Obtained article text for link:  2425
# Processing link:  2426
# Obtained article text for link:  2426
# Processing link:  2427
# Obtained article text for link:  2427
# Processing link:  2428
# Obtained article text for link:  2428
# Processing link:  2429
# Obtained article text for link:  2429
# Processing link:  2430
# Obtained article text for link:  2430
# Processing link:  2431
# Obtained article text for link:  2431
# Processing link:  2432
# Obtained article text for link:  2432
# Processing link:  2433
# Obtained article text for link:  2433
# Processing link:  2434
# Obtained article text for link:  2434
# Processing link:  2435
# Obtained article text for link:  2435
# Processing link:  2436
# Obtained article text for link:  2436
# Processing link:  2437
# Obtained article text for link:  2437
# Processing link:  2438
# Obtained article text for link:  2438
# Processing link:  2439
# Obtained article text for link:  2439
# Processing link:  2440
# Obtained article text for link:  2440
# Processing link:  2441
# Obtained article text for link:  2441
# Processing link:  2442
# Obtained article text for link:  2442
# Processing link:  2443
# Obtained article text for link:  2443
# Processing link:  2444
# Obtained article text for link:  2444
# Processing link:  2445
# Obtained article text for link:  2445
# Processing link:  2446
# Obtained article text for link:  2446
# Processing link:  2447
# Obtained article text for link:  2447
# Processing link:  2448
# Obtained article text for link:  2448
# Processing link:  2449
# Obtained article text for link:  2449
# Processing link:  2450
# Obtained article text for link:  2450
# Processing link:  2451
# Obtained article text for link:  2451
# Processing link:  2452
# Obtained article text for link:  2452
# Processing link:  2453
# Obtained article text for link:  2453
# Processing link:  2454
# Obtained article text for link:  2454
# Processing link:  2455
# Obtained article text for link:  2455
# Processing link:  2456
# Obtained article text for link:  2456
# Processing link:  2457
# Obtained article text for link:  2457
# Processing link:  2458
# Obtained article text for link:  2458
# Processing link:  2459
# Obtained article text for link:  2459
# Processing link:  2460
# Obtained article text for link:  2460
# Processing link:  2461
# Obtained article text for link:  2461
# Processing link:  2462
# Obtained article text for link:  2462
# Processing link:  2463
# Obtained article text for link:  2463
# Processing link:  2464
# Obtained article text for link:  2464
# Processing link:  2465
# Obtained article text for link:  2465
# Processing link:  2466
# Obtained article text for link:  2466
# Processing link:  2467
# Obtained article text for link:  2467
# Processing link:  2468
# Obtained article text for link:  2468
# Processing link:  2469
# Obtained article text for link:  2469
# Processing link:  2470
# Obtained article text for link:  2470
# Processing link:  2471
# Obtained article text for link:  2471
# Processing link:  2472
# Obtained article text for link:  2472
# Processing link:  2473
# Obtained article text for link:  2473
# Processing link:  2474
# Obtained article text for link:  2474
# Processing link:  2475
# Obtained article text for link:  2475
# Processing link:  2476
# Obtained article text for link:  2476
# Processing link:  2477
# Obtained article text for link:  2477
# Processing link:  2478
# Obtained article text for link:  2478
# Processing link:  2479
# Obtained article text for link:  2479
# Processing link:  2480
# Obtained article text for link:  2480
# Processing link:  2481
# Obtained article text for link:  2481
# Processing link:  2482
# Obtained article text for link:  2482
# Processing link:  2483
# Obtained article text for link:  2483
# Processing link:  2484
# Obtained article text for link:  2484
# Processing link:  2485
# Obtained article text for link:  2485
# Processing link:  2486
# Obtained article text for link:  2486
# Processing link:  2487
# Obtained article text for link:  2487
# Processing link:  2488
# Obtained article text for link:  2488
# Processing link:  2489
# Obtained article text for link:  2489
# Processing link:  2490
# Obtained article text for link:  2490
# Processing link:  2491
# Obtained article text for link:  2491
# Processing link:  2492
# Obtained article text for link:  2492
# Processing link:  2493
# Obtained article text for link:  2493
# Processing link:  2494
# Obtained article text for link:  2494
# Processing link:  2495
# Obtained article text for link:  2495
# Processing link:  2496
# Obtained article text for link:  2496
# Processing link:  2497
# Obtained article text for link:  2497
# Processing link:  2498
# Obtained article text for link:  2498
# Processing link:  2499
# Obtained article text for link:  2499
# Processing link:  2500
# Obtained article text for link:  2500
# Processing link:  2501
# Obtained article text for link:  2501
# Processing link:  2502
# Obtained article text for link:  2502
# Processing link:  2503
# Obtained article text for link:  2503
# Processing link:  2504
# Obtained article text for link:  2504
# Processing link:  2505
# Obtained article text for link:  2505
# Processing link:  2506
# Obtained article text for link:  2506
# Processing link:  2507
# Obtained article text for link:  2507

# %%
site_data['Content'] = article_text
site_data.to_csv('hemetro_with_text.csv', encoding='utf-8', index=False)
site_data
# Out:
#                                                   Title        Date      Time  \
# 0     Perolehan vaksin: Cubaan ketiga Anwar burukkan PN  2023-02-18  22:09:02
# 1     NPRA, KKM nafi vaksin Covid-19 mengandungi cip ID  2023-02-03  16:27:44
# 2     Tiada laporan kes strok dalam kajian vaksin Co...  2023-01-18  18:55:20
# 3     130 rakyat Singapura tersalah terima dos vaksi...  2022-10-04  10:01:28
# 4                   1.5 juta kanak-kanak belum divaksin  2022-07-28  13:24:14
# ...                                                 ...         ...       ...
# 2503  Kuarantin selaras ajaran Islam, dipraktikkan d...  2020-02-02  00:01:30
# 2504          WEF2020: Apa langkah Malaysia seterusnya?  2020-02-01  19:03:48
# 2505          Virus Corona: Kembali kepada sistem Islam  2020-01-26  17:43:59
# 2506  Penyakit Influenza Virus Corona Wuhan (2019 n-...  2020-01-26  08:46:49
# 2507      Insentif e-Tunai, bimbang keselamatan digital  2020-01-16  06:08:09
#
#                                                    Link Post_Category  \
# 0     https://harakahdaily.net/index.php/2023/02/18/...      Nasional
# 1     https://harakahdaily.net/index.php/2023/02/03/...      Nasional
# 2     https://harakahdaily.net/index.php/2023/01/18/...        Berita
# 3     https://harakahdaily.net/index.php/2022/10/04/...        Global
# 4     https://harakahdaily.net/index.php/2022/07/28/...      Nasional
# ...                                                 ...           ...
# 2503  https://harakahdaily.net/index.php/2020/02/02/...      Nasional
# 2504  https://harakahdaily.net/index.php/2020/02/01/...        Global
# 2505  https://harakahdaily.net/index.php/2020/01/26/...        Global
# 2506  https://harakahdaily.net/index.php/2020/01/26/...        Berita
# 2507  https://harakahdaily.net/index.php/2020/01/16/...        Berita
#
#                                                 Content
# 0     ANWAR kata perolehan vaksin COVID-19 tak ikut ...
# 1     KUALA LUMPUR: Bahagian Regulatori Farmasi Nega...
# 2     KUALA LUMPUR: Tiada pelaporan kes strok untuk ...
# 3     SINGAPURA: Seramai 130 rakyat Singapura telah ...
# 4     Oleh SYAHIRAH SALLEHKUALA LUMPUR: Seramai 1,51...
# ...                                                 ...
# 2503  SERUAN untuk mengisolasi sebuah daerah yang di...
# 2504  TIDAK banyak liputan media tempatan mengenai W...
# 2505  CHINA diserang virus  (1)     Hari ini kita di...
# 2506  JANGKITAN Influenza Wuhan merupakan penyakit s...
# 2507  KUALA LUMPUR: Kerajaan mengumumkan peruntukan ...
#
# [2508 rows x 6 columns]
