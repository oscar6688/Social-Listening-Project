# %%
import sys 
import time 
import requests 
import csv

from bs4 import BeautifulSoup 
from datetime import datetime
from fake_useragent import UserAgent

# %%
def extract_properties(links, writer):
    # need to get the first 6 articles, as the other 4 are the 'popular section'
    for link in links[:6]:
      # Within div tag, find h3 tag, then within h3 find 'a' tag, extract its title as text

      # Ex: Perolehan vaksin: Cubaan ketiga Anwar burukkan PN 

      article_title = link.find('h3').find('a').text

      # Ex: Date 2023-02-18T22:09:02+00:00
      date = link.find('time')['datetime'][:10]

      # Ex: 2023-02-18
      dateobj = datetime.strptime(date,'%Y-%m-%d').date()
      
      # Ex: 22:09:02+00:00 --> 22:09:02
      time = link.find('time')['datetime'][11:19]

      # Ex: 22:09:02 --> datetime format
      timeobj = datetime.strptime(time, '%H:%M:%S').time()

      # Extract value of href attribute from 'a' tag using dictionary-style access
      Link = link.find('h3').find('a')['href']

      # write each as a row in csv file
      writer.writerow([article_title, dateobj, timeobj, Link])

# %%
# Jan 2020 - Dec 2022 is in total 418 pages 

pages_to_get = 418

# Writing to a file 
with open('harakah_daily.csv', 'w', newline='') as f:
  writer = csv.writer(f)
  headers = ["Title", "Date", "Time", "Link"]
  writer.writerow(headers)

  # automatic goes to the next page from 1... n; python exclusive end 

  for page in range(1,pages_to_get+1):
    print('Processing Page: ', page)
    url = 'https://harakahdaily.net/index.php/page/'+str(page)+'/?s=vaksin'

    try:
      # response is equivalent to enter a key in chrome 
      # prevent ip-block by adding fake devices accessing web pages 
      response = requests.get(url, headers={'User-Agent': UserAgent().random})

      # this link give valid status code: 200 --> web scrap pass 
      # print(page.status_code)

    except Exception as e:
      error_type, error_obj, error_info = sys.exc_info()
      print('Error Link: ', url)
      print(error_type, 'Line: ', error_info.tb_lineno)

      # ignore this paage and move on to next one
      continue 

    # delay by 2 seconds to prevent ip block
    time.sleep(2)

    soup = BeautifulSoup(response.text, 'html.parser')
    # inspect element attribute type and its names to take their information

    attrs_code = 'item-details'
    links = soup.find_all('div', attrs={'class':attrs_code})
    # print(len(links))

    # Check each page has 6 links
    print(f'This page has {len(links[:6])} links')

    extract_properties(links, writer)

    print('CSV file saved successfully for Page: ' + str(page))
# Out:
# Processing Page:  1
# This page has 6 links
# CSV file saved successfully for Page: 1
# Processing Page:  2
# This page has 6 links
# CSV file saved successfully for Page: 2
# Processing Page:  3
# This page has 6 links
# CSV file saved successfully for Page: 3
# Processing Page:  4
# This page has 6 links
# CSV file saved successfully for Page: 4
# Processing Page:  5
# This page has 6 links
# CSV file saved successfully for Page: 5
# Processing Page:  6
# This page has 6 links
# CSV file saved successfully for Page: 6
# Processing Page:  7
# This page has 6 links
# CSV file saved successfully for Page: 7
# Processing Page:  8
# This page has 6 links
# CSV file saved successfully for Page: 8
# Processing Page:  9
# This page has 6 links
# CSV file saved successfully for Page: 9
# Processing Page:  10
# This page has 6 links
# CSV file saved successfully for Page: 10
# Processing Page:  11
# This page has 6 links
# CSV file saved successfully for Page: 11
# Processing Page:  12
# This page has 6 links
# CSV file saved successfully for Page: 12
# Processing Page:  13
# This page has 6 links
# CSV file saved successfully for Page: 13
# Processing Page:  14
# This page has 6 links
# CSV file saved successfully for Page: 14
# Processing Page:  15
# This page has 6 links
# CSV file saved successfully for Page: 15
# Processing Page:  16
# This page has 6 links
# CSV file saved successfully for Page: 16
# Processing Page:  17
# This page has 6 links
# CSV file saved successfully for Page: 17
# Processing Page:  18
# This page has 6 links
# CSV file saved successfully for Page: 18
# Processing Page:  19
# This page has 6 links
# CSV file saved successfully for Page: 19
# Processing Page:  20
# This page has 6 links
# CSV file saved successfully for Page: 20
# Processing Page:  21
# This page has 6 links
# CSV file saved successfully for Page: 21
# Processing Page:  22
# This page has 6 links
# CSV file saved successfully for Page: 22
# Processing Page:  23
# This page has 6 links
# CSV file saved successfully for Page: 23
# Processing Page:  24
# This page has 6 links
# CSV file saved successfully for Page: 24
# Processing Page:  25
# This page has 6 links
# CSV file saved successfully for Page: 25
# Processing Page:  26
# This page has 6 links
# CSV file saved successfully for Page: 26
# Processing Page:  27
# This page has 6 links
# CSV file saved successfully for Page: 27
# Processing Page:  28
# This page has 6 links
# CSV file saved successfully for Page: 28
# Processing Page:  29
# This page has 6 links
# CSV file saved successfully for Page: 29
# Processing Page:  30
# This page has 6 links
# CSV file saved successfully for Page: 30
# Processing Page:  31
# This page has 6 links
# CSV file saved successfully for Page: 31
# Processing Page:  32
# This page has 6 links
# CSV file saved successfully for Page: 32
# Processing Page:  33
# This page has 6 links
# CSV file saved successfully for Page: 33
# Processing Page:  34
# This page has 6 links
# CSV file saved successfully for Page: 34
# Processing Page:  35
# This page has 6 links
# CSV file saved successfully for Page: 35
# Processing Page:  36
# This page has 6 links
# CSV file saved successfully for Page: 36
# Processing Page:  37
# This page has 6 links
# CSV file saved successfully for Page: 37
# Processing Page:  38
# This page has 6 links
# CSV file saved successfully for Page: 38
# Processing Page:  39
# This page has 6 links
# CSV file saved successfully for Page: 39
# Processing Page:  40
# This page has 6 links
# CSV file saved successfully for Page: 40
# Processing Page:  41
# This page has 6 links
# CSV file saved successfully for Page: 41
# Processing Page:  42
# This page has 6 links
# CSV file saved successfully for Page: 42
# Processing Page:  43
# This page has 6 links
# CSV file saved successfully for Page: 43
# Processing Page:  44
# This page has 6 links
# CSV file saved successfully for Page: 44
# Processing Page:  45
# This page has 6 links
# CSV file saved successfully for Page: 45
# Processing Page:  46
# This page has 6 links
# CSV file saved successfully for Page: 46
# Processing Page:  47
# This page has 6 links
# CSV file saved successfully for Page: 47
# Processing Page:  48
# This page has 6 links
# CSV file saved successfully for Page: 48
# Processing Page:  49
# This page has 6 links
# CSV file saved successfully for Page: 49
# Processing Page:  50
# This page has 6 links
# CSV file saved successfully for Page: 50
# Processing Page:  51
# This page has 6 links
# CSV file saved successfully for Page: 51
# Processing Page:  52
# This page has 6 links
# CSV file saved successfully for Page: 52
# Processing Page:  53
# This page has 6 links
# CSV file saved successfully for Page: 53
# Processing Page:  54
# This page has 6 links
# CSV file saved successfully for Page: 54
# Processing Page:  55
# This page has 6 links
# CSV file saved successfully for Page: 55
# Processing Page:  56
# This page has 6 links
# CSV file saved successfully for Page: 56
# Processing Page:  57
# This page has 6 links
# CSV file saved successfully for Page: 57
# Processing Page:  58
# This page has 6 links
# CSV file saved successfully for Page: 58
# Processing Page:  59
# This page has 6 links
# CSV file saved successfully for Page: 59
# Processing Page:  60
# This page has 6 links
# CSV file saved successfully for Page: 60
# Processing Page:  61
# This page has 6 links
# CSV file saved successfully for Page: 61
# Processing Page:  62
# This page has 6 links
# CSV file saved successfully for Page: 62
# Processing Page:  63
# This page has 6 links
# CSV file saved successfully for Page: 63
# Processing Page:  64
# This page has 6 links
# CSV file saved successfully for Page: 64
# Processing Page:  65
# This page has 6 links
# CSV file saved successfully for Page: 65
# Processing Page:  66
# This page has 6 links
# CSV file saved successfully for Page: 66
# Processing Page:  67
# This page has 6 links
# CSV file saved successfully for Page: 67
# Processing Page:  68
# This page has 6 links
# CSV file saved successfully for Page: 68
# Processing Page:  69
# This page has 6 links
# CSV file saved successfully for Page: 69
# Processing Page:  70
# This page has 6 links
# CSV file saved successfully for Page: 70
# Processing Page:  71
# This page has 6 links
# CSV file saved successfully for Page: 71
# Processing Page:  72
# This page has 6 links
# CSV file saved successfully for Page: 72
# Processing Page:  73
# This page has 6 links
# CSV file saved successfully for Page: 73
# Processing Page:  74
# This page has 6 links
# CSV file saved successfully for Page: 74
# Processing Page:  75
# This page has 6 links
# CSV file saved successfully for Page: 75
# Processing Page:  76
# This page has 6 links
# CSV file saved successfully for Page: 76
# Processing Page:  77
# This page has 6 links
# CSV file saved successfully for Page: 77
# Processing Page:  78
# This page has 6 links
# CSV file saved successfully for Page: 78
# Processing Page:  79
# This page has 6 links
# CSV file saved successfully for Page: 79
# Processing Page:  80
# This page has 6 links
# CSV file saved successfully for Page: 80
# Processing Page:  81
# This page has 6 links
# CSV file saved successfully for Page: 81
# Processing Page:  82
# This page has 6 links
# CSV file saved successfully for Page: 82
# Processing Page:  83
# This page has 6 links
# CSV file saved successfully for Page: 83
# Processing Page:  84
# This page has 6 links
# CSV file saved successfully for Page: 84
# Processing Page:  85
# This page has 6 links
# CSV file saved successfully for Page: 85
# Processing Page:  86
# This page has 6 links
# CSV file saved successfully for Page: 86
# Processing Page:  87
# This page has 6 links
# CSV file saved successfully for Page: 87
# Processing Page:  88
# This page has 6 links
# CSV file saved successfully for Page: 88
# Processing Page:  89
# This page has 6 links
# CSV file saved successfully for Page: 89
# Processing Page:  90
# This page has 6 links
# CSV file saved successfully for Page: 90
# Processing Page:  91
# This page has 6 links
# CSV file saved successfully for Page: 91
# Processing Page:  92
# This page has 6 links
# CSV file saved successfully for Page: 92
# Processing Page:  93
# This page has 6 links
# CSV file saved successfully for Page: 93
# Processing Page:  94
# This page has 6 links
# CSV file saved successfully for Page: 94
# Processing Page:  95
# This page has 6 links
# CSV file saved successfully for Page: 95
# Processing Page:  96
# This page has 6 links
# CSV file saved successfully for Page: 96
# Processing Page:  97
# This page has 6 links
# CSV file saved successfully for Page: 97
# Processing Page:  98
# This page has 6 links
# CSV file saved successfully for Page: 98
# Processing Page:  99
# This page has 6 links
# CSV file saved successfully for Page: 99
# Processing Page:  100
# This page has 6 links
# CSV file saved successfully for Page: 100
# Processing Page:  101
# This page has 6 links
# CSV file saved successfully for Page: 101
# Processing Page:  102
# This page has 6 links
# CSV file saved successfully for Page: 102
# Processing Page:  103
# This page has 6 links
# CSV file saved successfully for Page: 103
# Processing Page:  104
# This page has 6 links
# CSV file saved successfully for Page: 104
# Processing Page:  105
# This page has 6 links
# CSV file saved successfully for Page: 105
# Processing Page:  106
# This page has 6 links
# CSV file saved successfully for Page: 106
# Processing Page:  107
# This page has 6 links
# CSV file saved successfully for Page: 107
# Processing Page:  108
# This page has 6 links
# CSV file saved successfully for Page: 108
# Processing Page:  109
# This page has 6 links
# CSV file saved successfully for Page: 109
# Processing Page:  110
# This page has 6 links
# CSV file saved successfully for Page: 110
# Processing Page:  111
# This page has 6 links
# CSV file saved successfully for Page: 111
# Processing Page:  112
# This page has 6 links
# CSV file saved successfully for Page: 112
# Processing Page:  113
# This page has 6 links
# CSV file saved successfully for Page: 113
# Processing Page:  114
# This page has 6 links
# CSV file saved successfully for Page: 114
# Processing Page:  115
# This page has 6 links
# CSV file saved successfully for Page: 115
# Processing Page:  116
# This page has 6 links
# CSV file saved successfully for Page: 116
# Processing Page:  117
# This page has 6 links
# CSV file saved successfully for Page: 117
# Processing Page:  118
# This page has 6 links
# CSV file saved successfully for Page: 118
# Processing Page:  119
# This page has 6 links
# CSV file saved successfully for Page: 119
# Processing Page:  120
# This page has 6 links
# CSV file saved successfully for Page: 120
# Processing Page:  121
# This page has 6 links
# CSV file saved successfully for Page: 121
# Processing Page:  122
# This page has 6 links
# CSV file saved successfully for Page: 122
# Processing Page:  123
# This page has 6 links
# CSV file saved successfully for Page: 123
# Processing Page:  124
# This page has 6 links
# CSV file saved successfully for Page: 124
# Processing Page:  125
# This page has 6 links
# CSV file saved successfully for Page: 125
# Processing Page:  126
# This page has 6 links
# CSV file saved successfully for Page: 126
# Processing Page:  127
# This page has 6 links
# CSV file saved successfully for Page: 127
# Processing Page:  128
# This page has 6 links
# CSV file saved successfully for Page: 128
# Processing Page:  129
# This page has 6 links
# CSV file saved successfully for Page: 129
# Processing Page:  130
# This page has 6 links
# CSV file saved successfully for Page: 130
# Processing Page:  131
# This page has 6 links
# CSV file saved successfully for Page: 131
# Processing Page:  132
# This page has 6 links
# CSV file saved successfully for Page: 132
# Processing Page:  133
# This page has 6 links
# CSV file saved successfully for Page: 133
# Processing Page:  134
# This page has 6 links
# CSV file saved successfully for Page: 134
# Processing Page:  135
# This page has 6 links
# CSV file saved successfully for Page: 135
# Processing Page:  136
# This page has 6 links
# CSV file saved successfully for Page: 136
# Processing Page:  137
# This page has 6 links
# CSV file saved successfully for Page: 137
# Processing Page:  138
# This page has 6 links
# CSV file saved successfully for Page: 138
# Processing Page:  139
# This page has 6 links
# CSV file saved successfully for Page: 139
# Processing Page:  140
# This page has 6 links
# CSV file saved successfully for Page: 140
# Processing Page:  141
# This page has 6 links
# CSV file saved successfully for Page: 141
# Processing Page:  142
# This page has 6 links
# CSV file saved successfully for Page: 142
# Processing Page:  143
# This page has 6 links
# CSV file saved successfully for Page: 143
# Processing Page:  144
# This page has 6 links
# CSV file saved successfully for Page: 144
# Processing Page:  145
# This page has 6 links
# CSV file saved successfully for Page: 145
# Processing Page:  146
# This page has 6 links
# CSV file saved successfully for Page: 146
# Processing Page:  147
# This page has 6 links
# CSV file saved successfully for Page: 147
# Processing Page:  148
# This page has 6 links
# CSV file saved successfully for Page: 148
# Processing Page:  149
# This page has 6 links
# CSV file saved successfully for Page: 149
# Processing Page:  150
# This page has 6 links
# CSV file saved successfully for Page: 150
# Processing Page:  151
# This page has 6 links
# CSV file saved successfully for Page: 151
# Processing Page:  152
# This page has 6 links
# CSV file saved successfully for Page: 152
# Processing Page:  153
# This page has 6 links
# CSV file saved successfully for Page: 153
# Processing Page:  154
# This page has 6 links
# CSV file saved successfully for Page: 154
# Processing Page:  155
# This page has 6 links
# CSV file saved successfully for Page: 155
# Processing Page:  156
# This page has 6 links
# CSV file saved successfully for Page: 156
# Processing Page:  157
# This page has 6 links
# CSV file saved successfully for Page: 157
# Processing Page:  158
# This page has 6 links
# CSV file saved successfully for Page: 158
# Processing Page:  159
# This page has 6 links
# CSV file saved successfully for Page: 159
# Processing Page:  160
# This page has 6 links
# CSV file saved successfully for Page: 160
# Processing Page:  161
# This page has 6 links
# CSV file saved successfully for Page: 161
# Processing Page:  162
# This page has 6 links
# CSV file saved successfully for Page: 162
# Processing Page:  163
# This page has 6 links
# CSV file saved successfully for Page: 163
# Processing Page:  164
# This page has 6 links
# CSV file saved successfully for Page: 164
# Processing Page:  165
# This page has 6 links
# CSV file saved successfully for Page: 165
# Processing Page:  166
# This page has 6 links
# CSV file saved successfully for Page: 166
# Processing Page:  167
# This page has 6 links
# CSV file saved successfully for Page: 167
# Processing Page:  168
# This page has 6 links
# CSV file saved successfully for Page: 168
# Processing Page:  169
# This page has 6 links
# CSV file saved successfully for Page: 169
# Processing Page:  170
# This page has 6 links
# CSV file saved successfully for Page: 170
# Processing Page:  171
# This page has 6 links
# CSV file saved successfully for Page: 171
# Processing Page:  172
# This page has 6 links
# CSV file saved successfully for Page: 172
# Processing Page:  173
# This page has 6 links
# CSV file saved successfully for Page: 173
# Processing Page:  174
# This page has 6 links
# CSV file saved successfully for Page: 174
# Processing Page:  175
# This page has 6 links
# CSV file saved successfully for Page: 175
# Processing Page:  176
# This page has 6 links
# CSV file saved successfully for Page: 176
# Processing Page:  177
# This page has 6 links
# CSV file saved successfully for Page: 177
# Processing Page:  178
# This page has 6 links
# CSV file saved successfully for Page: 178
# Processing Page:  179
# This page has 6 links
# CSV file saved successfully for Page: 179
# Processing Page:  180
# This page has 6 links
# CSV file saved successfully for Page: 180
# Processing Page:  181
# This page has 6 links
# CSV file saved successfully for Page: 181
# Processing Page:  182
# This page has 6 links
# CSV file saved successfully for Page: 182
# Processing Page:  183
# This page has 6 links
# CSV file saved successfully for Page: 183
# Processing Page:  184
# This page has 6 links
# CSV file saved successfully for Page: 184
# Processing Page:  185
# This page has 6 links
# CSV file saved successfully for Page: 185
# Processing Page:  186
# This page has 6 links
# CSV file saved successfully for Page: 186
# Processing Page:  187
# This page has 6 links
# CSV file saved successfully for Page: 187
# Processing Page:  188
# This page has 6 links
# CSV file saved successfully for Page: 188
# Processing Page:  189
# This page has 6 links
# CSV file saved successfully for Page: 189
# Processing Page:  190
# This page has 6 links
# CSV file saved successfully for Page: 190
# Processing Page:  191
# This page has 6 links
# CSV file saved successfully for Page: 191
# Processing Page:  192
# This page has 6 links
# CSV file saved successfully for Page: 192
# Processing Page:  193
# This page has 6 links
# CSV file saved successfully for Page: 193
# Processing Page:  194
# This page has 6 links
# CSV file saved successfully for Page: 194
# Processing Page:  195
# This page has 6 links
# CSV file saved successfully for Page: 195
# Processing Page:  196
# This page has 6 links
# CSV file saved successfully for Page: 196
# Processing Page:  197
# This page has 6 links
# CSV file saved successfully for Page: 197
# Processing Page:  198
# This page has 6 links
# CSV file saved successfully for Page: 198
# Processing Page:  199
# This page has 6 links
# CSV file saved successfully for Page: 199
# Processing Page:  200
# This page has 6 links
# CSV file saved successfully for Page: 200
# Processing Page:  201
# This page has 6 links
# CSV file saved successfully for Page: 201
# Processing Page:  202
# This page has 6 links
# CSV file saved successfully for Page: 202
# Processing Page:  203
# This page has 6 links
# CSV file saved successfully for Page: 203
# Processing Page:  204
# This page has 6 links
# CSV file saved successfully for Page: 204
# Processing Page:  205
# This page has 6 links
# CSV file saved successfully for Page: 205
# Processing Page:  206
# This page has 6 links
# CSV file saved successfully for Page: 206
# Processing Page:  207
# This page has 6 links
# CSV file saved successfully for Page: 207
# Processing Page:  208
# This page has 6 links
# CSV file saved successfully for Page: 208
# Processing Page:  209
# This page has 6 links
# CSV file saved successfully for Page: 209
# Processing Page:  210
# This page has 6 links
# CSV file saved successfully for Page: 210
# Processing Page:  211
# This page has 6 links
# CSV file saved successfully for Page: 211
# Processing Page:  212
# This page has 6 links
# CSV file saved successfully for Page: 212
# Processing Page:  213
# This page has 6 links
# CSV file saved successfully for Page: 213
# Processing Page:  214
